# %% [markdown]
# # **Building & Evaluating a RAG Application using Qdrant and RAGAS**
#
# **Introduction**
#
# Creating a foundation for a Retrieval-Augmented Generation (RAG) pipeline is often straightforward. However, optimizing and tweaking it for production and ensuring top-notch response quality presents formidable hurdles. Given the multitude of tools and parameters available, identifying the ideal configuration can feel overwhelming.
#
# In this notebook, we delve into the evaluation, visualization, and analysis of RAG systems using a blend of open-source libraries. Our toolkit includes [RAGAS](https://docs.ragas.io/) for evaluation and Qdrant for context augmentation, serving as a vector database to construct the RAG pipeline.
#
# Throughout this article, we'll leverage data sourced from [Qdrant](https://qdrant.tech/)'s documentation and articles to create an assistant capable of answering queries about Qdrant. Additionally, we'll explore methods for generating synthetic test data, including those provided by RAGAS.
#
# ❗This notebook requires **OpenAI Key**

# %% [markdown]
# ### **1. Import relevant packages**

# %%
import os
import json
import openai
import pandas as pd
import qdrant_client
import tqdm as tqdm
from getpass import getpass
from dotenv import load_dotenv
from datasets import load_dataset
from typing import Optional, List, Tuple
from qdrant_client import QdrantClient, models
from qdrant_client.http.models import PointStruct
from langchain_core.language_models import BaseChatModel

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# ### **2. Setup your openai key**

# %%
if not (openai_api_key := os.environ.get("OPENAI_API_KEY")):
    openai_api_key = getpass("🔑 Enter your OpenAI API key: ")
openai.api_key = openai_api_key
os.environ["OPENAI_API_KEY"] = openai_api_key

# %% [markdown]
# ### **3.  Retrieve the documents / dataset to be used**

# %%
dataset = load_dataset("atitaarora/qdrant_doc", split="train")

# %%
len(dataset)
# Out:
# 491

# %% [markdown]
# ### **4. Process dataset as langchain document for further processing**

# %%
from tqdm import tqdm
from langchain.docstore.document import Document as LangchainDocument

## Dataset to langchain document
langchain_docs = [
    LangchainDocument(page_content=doc["text"], metadata={"source": doc["source"]})
    for doc in tqdm(dataset)
]

len(langchain_docs)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 491/491 [00:00<00:00, 13030.32it/s]
# 491

# %% [markdown]
# ### **5. Document chunk processing**
#
# Processing each document with desired **TEXT_SPLITTER_ALGO , CHUNK_SIZE , CHUNK_OVERLAP** etc

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

## Check https://python.langchain.com/v0.2/docs/concepts/#text-splitters for supported text splitters
def split_documents(documents,chunk_size,chunk_overlap):
    docs_processed = []
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=chunk_size,
        chunk_overlap=chunk_overlap,
        add_start_index=True,
        separators=["\n\n", "\n", ".", " ", ""],
    )
    for doc in documents:
        docs_processed += text_splitter.split_documents([doc])
    return docs_processed

# %%
CHUNK_SIZE=512
CHUNK_OVERLAP=50
processed_docs = split_documents(langchain_docs,CHUNK_SIZE,CHUNK_OVERLAP)
len(processed_docs)
# Out:
# 9267

# %% [markdown]
# ### **6. Embedding Generation using Fastembed**
# [FastEmbed](https://qdrant.github.io/fastembed/) is a lightweight, fast, Python library built for embedding generation.

# %%
## Declaring the intended Embedding Model with Fastembed
from fastembed.embedding import TextEmbedding

pd.DataFrame(TextEmbedding.list_supported_models())
# Out:
# 2024-09-23 10:47:26.273 | WARNING  | fastembed.embedding:<module>:7 - DefaultEmbedding, FlagEmbedding, JinaEmbedding are deprecated.Use from fastembed import TextEmbedding instead.
#                                                 model   dim  \
# 0                                    BAAI/bge-base-en   768
# 1                               BAAI/bge-base-en-v1.5   768
# 2                              BAAI/bge-large-en-v1.5  1024
# 3                                   BAAI/bge-small-en   384
# 4                              BAAI/bge-small-en-v1.5   384
# 5                              BAAI/bge-small-zh-v1.5   512
# 6   sentence-transformers/paraphrase-multilingual-...   384
# 7                                  thenlper/gte-large  1024
# 8                  mixedbread-ai/mxbai-embed-large-v1  1024
# 9                 snowflake/snowflake-arctic-embed-xs   384
# 10                 snowflake/snowflake-arctic-embed-s   384
# 11                 snowflake/snowflake-arctic-embed-m   768
# 12            snowflake/snowflake-arctic-embed-m-long   768
# 13                 snowflake/snowflake-arctic-embed-l  1024
# 14                     intfloat/multilingual-e5-large  1024
# 15  sentence-transformers/paraphrase-multilingual-...   768
# 16                          Qdrant/clip-ViT-B-32-text   512
# 17             sentence-transformers/all-MiniLM-L6-v2   384
# 18                  jinaai/jina-embeddings-v2-base-en   768
# 19                 jinaai/jina-embeddings-v2-small-en   512
# 20                  jinaai/jina-embeddings-v2-base-de   768
# 21                jinaai/jina-embeddings-v2-base-code   768
# 22                     nomic-ai/nomic-embed-text-v1.5   768
# 23                   nomic-ai/nomic-embed-text-v1.5-Q   768
# 24                       nomic-ai/nomic-embed-text-v1   768
#
#                                           description  size_in_GB  \
# 0   Text embeddings, Unimodal (text), English, 512...       0.420
# 1   Text embeddings, Unimodal (text), English, 512...       0.210
# 2   Text embeddings, Unimodal (text), English, 512...       1.200
# 3   Text embeddings, Unimodal (text), English, 512...       0.130
# 4   Text embeddings, Unimodal (text), English, 512...       0.067
# 5   Text embeddings, Unimodal (text), Chinese, 512...       0.090
# 6   Text embeddings, Unimodal (text), Multilingual...       0.220
# 7   Text embeddings, Unimodal (text), English, 512...       1.200
# 8   Text embeddings, Unimodal (text), English, 512...       0.640
# 9   Text embeddings, Unimodal (text), English, 512...       0.090
# 10  Text embeddings, Unimodal (text), English, 512...       0.130
# 11  Text embeddings, Unimodal (text), English, 512...       0.430
# 12  Text embeddings, Unimodal (text), English, 204...       0.540
# 13  Text embeddings, Unimodal (text), English, 512...       1.020
# 14  Text embeddings, Unimodal (text), Multilingual...       2.240
# 15  Text embeddings, Unimodal (text), Multilingual...       1.000
# 16  Text embeddings, Multimodal (text&image), Engl...       0.250
# 17  Text embeddings, Unimodal (text), English, 256...       0.090
# 18  Text embeddings, Unimodal (text), English, 819...       0.520
# 19  Text embeddings, Unimodal (text), English, 819...       0.120
# 20  Text embeddings, Unimodal (text), Multilingual...       0.320
# 21  Text embeddings, Unimodal (text), Multilingual...       0.640
# 22  Text embeddings, Multimodal (text, image), Eng...       0.520
# 23  Text embeddings, Multimodal (text, image), Eng...       0.130
# 24  Text embeddings, Multimodal (text, image), Eng...       0.520
#
#                                               sources  \
# 0   {'url': 'https://storage.googleapis.com/qdrant...
# 1   {'url': 'https://storage.googleapis.com/qdrant...
# 2             {'hf': 'qdrant/bge-large-en-v1.5-onnx'}
# 3   {'url': 'https://storage.googleapis.com/qdrant...
# 4           {'hf': 'qdrant/bge-small-en-v1.5-onnx-q'}
# 5   {'url': 'https://storage.googleapis.com/qdrant...
# 6   {'hf': 'qdrant/paraphrase-multilingual-MiniLM-...
# 7                     {'hf': 'qdrant/gte-large-onnx'}
# 8        {'hf': 'mixedbread-ai/mxbai-embed-large-v1'}
# 9       {'hf': 'snowflake/snowflake-arctic-embed-xs'}
# 10       {'hf': 'snowflake/snowflake-arctic-embed-s'}
# 11       {'hf': 'Snowflake/snowflake-arctic-embed-m'}
# 12  {'hf': 'snowflake/snowflake-arctic-embed-m-long'}
# 13       {'hf': 'snowflake/snowflake-arctic-embed-l'}
# 14  {'url': 'https://storage.googleapis.com/qdrant...
# 15  {'hf': 'xenova/paraphrase-multilingual-mpnet-b...
# 16                {'hf': 'Qdrant/clip-ViT-B-32-text'}
# 17  {'url': 'https://storage.googleapis.com/qdrant...
# 18        {'hf': 'xenova/jina-embeddings-v2-base-en'}
# 19       {'hf': 'xenova/jina-embeddings-v2-small-en'}
# 20        {'hf': 'jinaai/jina-embeddings-v2-base-de'}
# 21      {'hf': 'jinaai/jina-embeddings-v2-base-code'}
# 22           {'hf': 'nomic-ai/nomic-embed-text-v1.5'}
# 23           {'hf': 'nomic-ai/nomic-embed-text-v1.5'}
# 24             {'hf': 'nomic-ai/nomic-embed-text-v1'}
#
#                    model_file   additional_files
# 0        model_optimized.onnx                NaN
# 1        model_optimized.onnx                NaN
# 2                  model.onnx                NaN
# 3        model_optimized.onnx                NaN
# 4        model_optimized.onnx                NaN
# 5        model_optimized.onnx                NaN
# 6        model_optimized.onnx                NaN
# 7                  model.onnx                NaN
# 8             onnx/model.onnx                NaN
# 9             onnx/model.onnx                NaN
# 10            onnx/model.onnx                NaN
# 11            onnx/model.onnx                NaN
# 12            onnx/model.onnx                NaN
# 13            onnx/model.onnx                NaN
# 14                 model.onnx  [model.onnx_data]
# 15            onnx/model.onnx                NaN
# 16                 model.onnx                NaN
# 17                 model.onnx                NaN
# 18            onnx/model.onnx                NaN
# 19            onnx/model.onnx                NaN
# 20       onnx/model_fp16.onnx                NaN
# 21            onnx/model.onnx                NaN
# 22            onnx/model.onnx                NaN
# 23  onnx/model_quantized.onnx                NaN
# 24            onnx/model.onnx                NaN

# %%
##Initilising embedding model
## Using Default Model - BAAI/bge-small-en-v1.5
embedding_model = TextEmbedding()

## For custom model supported by Fastembed
#embedding_model = TextEmbedding(model_name="BAAI/bge-small-en", max_length=512)
#embedding_model = TextEmbedding(model_name="sentence-transformers/all-MiniLM-L6-v2", max_length=384)

embedding_model.model_name
# Out:
# Fetching 5 files: 100%|███████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 43873.47it/s]
# 'BAAI/bge-small-en-v1.5'

# %% [markdown]
# ### **7. Setting up our vector store - Qdrant**
#
# Set up the qdrant client and then create a collection so that our document embeddings can be stored.

# %%
##Uncomment to initialise qdrant client in memory
#client = qdrant_client.QdrantClient(
#    location=":memory:",
#)

##Uncomment below to connect to Qdrant Cloud
client = qdrant_client.QdrantClient(
    os.environ.get("QDRANT_URL"),
    api_key=os.environ.get("QDRANT_API_KEY"),
)

## Uncomment below to connect to local Qdrant
#client = qdrant_client.QdrantClient("http://localhost:6333")

# %%
## Collection name that will be used throughtout in the notebook
COLLECTION_NAME = "qdrant-docs-rag-langchain"

# %%
## General Collection level operations

## Get information about existing collections
client.get_collections()

## Get information about specific collection
#collection_info = client.get_collection(COLLECTION_NAME)
#print(collection_info)

## Deleting collection , if need be
#client.delete_collection(COLLECTION_NAME)
# Out:
# CollectionsResponse(collections=[CollectionDescription(name='posts'), CollectionDescription(name='users'), CollectionDescription(name='users_with_sparse'), CollectionDescription(name='qdrant-docs-rag-langchain')])

# %% [markdown]
# ### **8. Processing chunks into text to be processed by [FASTEMBED](https://qdrant.github.io/fastembed/)**

# %%
def process_document_embeddings(docs_processed):
    docs_contents = []
    docs_metadatas = []

    for doc in docs_processed:
        if hasattr(doc, 'page_content') and hasattr(doc, 'metadata'):
            docs_contents.append(doc.page_content)
            docs_metadatas.append(doc.metadata)
        else:
            # Handle the case where attributes are missing
            print("Warning: Some documents do not have 'page_content' or 'metadata' attributes.")
    
    print("data-size : ",len(docs_processed))
    print("content : ",len(docs_contents))
    print("metadata : ",len(docs_metadatas))
    return (docs_contents,docs_metadatas)

# %% [markdown]
# ### **9. Adding document chunks into Qdrant Collection**

# %%
docs_contents , docs_metadatas = process_document_embeddings(docs_processed=processed_docs)
# Out:
# data-size :  9267
# content :  9267
# metadata :  9267

# %%
client.add(collection_name=COLLECTION_NAME, metadata=docs_metadatas, documents=docs_contents)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 77.7M/77.7M [00:06<00:00, 11.6MiB/s]
# ['c1d65cf2815140049443b52a94ed4322',
#  '18c466a6cab645ddab4a81f0499d424c',
#  '562499cbb7564ae3b783535c5adbad55',
#  '7a61dc4a6f544d42859ad251505f8e6e',
#  '008a2a9f538d4fea909b8dce65ef9f7e',
#  'edc3a1888d7241ba8939ca3c181d4d6f',
#  'e517dab3cd474bc3b9b4245b0fd0d581',
#  '73741f8628154fd6894321e9bdafa47f',
#  'f85757746cbd4b269fe28d894ebbec69',
#  '2115b64c211f4430b109a71f4b57198b',
#  'fa4466982f4e4463b1fe8e6ed582ea79',
#  'f13dd2669b46459c81fd857b7e6bbf65',
#  '949541b833554a538fe3698e95440c04',
#  'c8a468acfd134b49afe7a34fdc7ea23f',
#  '898c44d5f8fc4172845f8115d2725b6f',
#  'f49fac7d36a54fbcafc790d272c721bc',
#  'c5f11f3cb8a8404abe5c30a20653f3a9',
#  '089d17a8cf354939a3ceba5894169249',
#  'ab61d7253fd1444e8512ab37ef99f43c',
#  '090bf344e9f541719bca17a9d2cf44f6',
#  '8bf4fc27b9cb4542bbb0566c9ffdc36d',
#  'e4cc73a5405741c7ad124504fed20ed9',
#  'c92d7951b3c848e0b9426453c8b8305e',
#  'e17b1795a7e04019ab8424a9435a4394',
#  '449aeca77c054b848e2492a9e29785ae',
#  'd9d544f7dd9548cfbfac5ac5d4dde25b',
#  'bb62e54f7d2841849362f1e3d1f472ac',
#  'ab83583e6d45468e9e8d972ccc6f28ad',
#  'ed10e8ad05424606bde155ee9b36dcdc',
#  '2e5866ac0c664695b2ff183c310f0e78',
#  'd47050e148ad4f598e6bd9bcc38131e5',
#  '21bb2fe9ffc84a04b27e66a063f98e29',
#  '32e9fa345ded4d068c0327c802e7a0f0',
#  '4cfc1c4fd6194efca4520073a34a3b08',
#  '13c768dafab24218908dd8f66313ab44',
#  '6e4c0a55a05848ef8350d73176ea8d12',
#  'b175eca046af49fdb0d41624d148ed85',
#  '853740b4140249fd880f19b3de348fbd',
#  'e42ffb6f96d84e628115f96dc94b61e0',
#  'ea95919a985242eca5b942dc6976a246',
#  'fb13547b0f3047a68bccf45ab42df545',
#  '55131bd51c444769b04c8b3b6761a06b',
#  '33405bd275354147a9d14681cccdb0ea',
#  ...]

# %%
## Ensuring we have expected number of document chunks
client.count(collection_name=COLLECTION_NAME)
# Out:
# CountResult(count=9267)

# %% [markdown]
# ### **10. Searching for the document**

# %%
## Searching for document chunks similar to query for context
search_result = client.query(collection_name=COLLECTION_NAME, query_text="what is binary quantization",limit=2)
context = ["document:"+r.document+",source:"+r.metadata['source'] for r in search_result]
for res in search_result:
    print("Id: ", res.id)
    print("Document : " , res.document)
    print("Score : " , res.score)
    print("Source : " , res.metadata['source'])
# Out:
# Id:  25cd5153-f5da-483e-9778-341b4f596953
# Document :  Here, we show how the accuracy of binary quantization is quite good across different dimensions -- for both the models.
#
#
#
# ## Enhanced performance and efficiency with binary quantization
# Score :  0.93278515
# Source :  articles/binary-quantization-openai.md
# Id:  06118494-99c1-4bcd-a7e1-a9d0cd9f3909
# Document :  Demetrios:
#
# I see, okay, so basically this is the quantization. And now let's dive into the binary quantization and how it works.
#
#
#
# Andrey Vasnetsov:
# Score :  0.9211246
# Source :  blog/binary-quantization-andrey-vasnetsov-vector-space-talk-001.md

# %% [markdown]
# ### **11. Inititalize OpenAI**

# %%
from openai import OpenAI
openai_client = OpenAI(api_key=openai_api_key)

# %% [markdown]
# ### **12. Querying without the context**

# %%
def query_without_context(query):

    prompt_start = (
        """ You're assisting a user who has a question based on the documentation.
        Your goal is to provide a clear and concise response that addresses their query while referencing relevant information 
        from the documentation.
        Remember to: 
        Understand the user's question thoroughly.
        If the user's query is general (e.g., "hi," "good morning"), 
        greet them normally and avoid using the context from the documentation.
        If the user's query is specific and related to the documentation, locate and extract the pertinent information.
        Craft a response that directly addresses the user's query and provides accurate information
        referring the relevant source and page from the 'source' field of fetched context from the documentation to support your answer.
        Use a friendly and professional tone in your response.
        If you cannot find the answer in the provided context, do not pretend to know it.
        Instead, respond with "I don't know".\n """
    )

    prompt_end = ( f"\n\nQuestion: {query}\nAnswer:" )

    prompt = ( prompt_start + "\n\n---\n\n" +  prompt_end )

    res = openai_client.completions.create(
        model="gpt-3.5-turbo-instruct",
        prompt=prompt,
        temperature=0,
        max_tokens=636,
        top_p=1,
        frequency_penalty=0,
        presence_penalty=0,
        stop=None
    )
    return (res.choices[0].text)

# %%
print (query_without_context(query = "what is binary quantization?"))
# Out:
#  Binary quantization is a process of converting numerical data into binary form, where each value is represented by a sequence of 0s and 1s. This technique is commonly used in machine learning and data compression to reduce the size of data while preserving its essential information. You can learn more about binary quantization and its applications on page 12 of the "Data Compression" section in the documentation.

# %%
print (query_without_context(query = "How can one reproduce the benchmark for Open Source vector databases?"))
# Out:
#  To reproduce the benchmark for Open Source vector databases, you can follow the steps outlined in the documentation on page 5 of the 'Benchmarking' section. This section provides detailed instructions on how to set up and run the benchmark, as well as how to interpret the results. Additionally, you can refer to the 'Benchmarking' section for more information on the benchmarking process and its importance in evaluating vector databases.

# %% [markdown]
# ### **13. Querying with Context from Qdrant**

# %%
def query_with_context(query,limit):

    ## Fetch context from Qdrant
    search_result = client.query(collection_name=COLLECTION_NAME, query_text=query, limit=limit)

    contexts = [
        "document:"+r.document+",source:"+r.metadata['source'] for r in search_result
    ]
    prompt_start = (
        """ You're assisting a user who has a question based on the documentation.
        Your goal is to provide a clear and concise response that addresses their query while referencing relevant information 
        from the documentation.
        Remember to: 
        Understand the user's question thoroughly.
        If the user's query is general (e.g., "hi," "good morning"), 
        greet them normally and avoid using the context from the documentation.
        If the user's query is specific and related to the documentation, locate and extract the pertinent information.
        Craft a response that directly addresses the user's query and provides accurate information
        referring the relevant source and page from the 'source' field of fetched context from the documentation to support your answer.
        Use a friendly and professional tone in your response.
        If you cannot find the answer in the provided context, do not pretend to know it.
        Instead, respond with "I don't know".
        
        Context:\n"""
    )

    prompt_end = (
        f"\n\nQuestion: {query}\nAnswer:"
    )

    prompt = (
        prompt_start + "\n\n---\n\n".join(contexts) +
        prompt_end
    )

    res = openai_client.completions.create(
        model="gpt-3.5-turbo-instruct",
        prompt=prompt,
        temperature=0,
        max_tokens=636,
        top_p=1,
        frequency_penalty=0,
        presence_penalty=0,
        stop=None
    )

    return (contexts , res.choices[0].text)

# %%
question1 = "what is quantization?"
question2 = "How can one reproduce the benchmark for Open Source vector databases?"

# %%
RETRIEVAL_WINDOW_SIZE_3 = 3
context2 , rag_response2 = query_with_context(question1,RETRIEVAL_WINDOW_SIZE_3)
#print(context)
print(rag_response2)
# Out:
#  Quantization is a technique that uses quantum computing to improve the search process in artificial neural networks (ANNs). It involves converting traditional float32 vectors into qbit vectors and creating quantum entanglement between them. This allows for highly efficient vector search algorithms to be developed. This information can be found in the article "Quantum Quantization and Entanglement" in the 'articles' section of the documentation.

# %%
RETRIEVAL_WINDOW_SIZE_5 = 5
context1 , rag_response1 = query_with_context(question1,RETRIEVAL_WINDOW_SIZE_5)
#print(context)
print(rag_response1)
# Out:
#  Quantization is a process that converts traditional float32 vectors into qbit vectors, creating quantum entanglement between the qbits. This allows for highly efficient vector search algorithms by leveraging the power of quantum computing. This information can be found in the article "Quantum Quantization and Entanglement" in the "Articles" section of the documentation.

# %%
context2_1 , rag_response2_1 = query_with_context(question2,RETRIEVAL_WINDOW_SIZE_3)
#print(context)
print(rag_response2_1)
# Out:
#  To reproduce the benchmark for Open Source vector databases, you can refer to the source code available on Github and follow the instructions in the README.md file. The benchmarks are fully open-sourced and contributions are welcome. This information can be found in the 'How to reproduce the benchmark?' section of the 'benchmarks/benchmark-faq.md' page.

# %%
context2_1 , rag_response2_1 = query_with_context(question2,RETRIEVAL_WINDOW_SIZE_5)
#print(context)
print(rag_response2_1)
# Out:
#  To reproduce the benchmark for Open Source vector databases, you can refer to the source code available on Github and follow the instructions in the README.md file. This information can be found in the source field of the document "benchmarks/benchmark-faq.md". Additionally, if you have any suggestions or improvements for the benchmark, you can contribute to the project on Github.

# %% [markdown]
# ### **13.1 Querying with Context from Qdrant with DSPy**

# %%
##Install DSPy and refer to documentation here : https://dspy-docs.vercel.app/docs/intro
# !pip install "dspy-ai[qdrant]"
# Out:
# /Users/atitaarora/.zshenv:2: command too long: /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/bin:/opt/homebrew/bin:/opt/homebrew/sbin:/usr/local/bin:/System/Cryptexes/App/usr/bin:/usr/bin:/bin:/usr/sbin:/sbin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/local/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/appleinternal/bin:/Library/Apple/usr/bin:/Users/atitaarora/.cargo/bin:/Applications/iTerm.app/Contents/Resources/utilities=/Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/bin:/opt/homebrew/bin:/opt/homebrew/sbin:/usr/local/bin:/System/Cryptexes/App/usr/bin:/usr/bin:/bin:/usr/sbin:/sbin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/local/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/appleinternal/bin:/Library/Apple/usr/bin:/Users/atitaarora/.cargo/bin:/Applications/iTerm.app/Contents/Resources/utilities+,,/Users/atitaarora/Library/Python/3.10/bin
# Collecting dspy-ai[qdrant]
#   Downloading dspy_ai-2.4.17-py3-none-any.whl.metadata (40 kB)
# Collecting backoff (from dspy-ai[qdrant])
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: datasets in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from dspy-ai[qdrant]) (2.21.0)
# Collecting joblib~=1.3 (from dspy-ai[qdrant])
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: openai<2.0.0,>=0.28.1 in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from dspy-ai[qdrant]) (1.47.0)
# Collecting optuna (from dspy-ai[qdrant])
#   Downloading optuna-4.0.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: pandas in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from dspy-ai[qdrant]) (2.2.3)
# Requirement already satisfied: pydantic~=2.0 in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from dspy-ai[qdrant]) (2.9.2)
# Requirement already satisfied: regex in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from dspy-ai[qdrant]) (2024.9.11)
# Requirement already satisfied: requests in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from dspy-ai[qdrant]) (2.32.3)
# Collecting structlog (from dspy-ai[qdrant])
#   Downloading structlog-24.4.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: tqdm in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from dspy-ai[qdrant]) (4.66.5)
# Collecting ujson (from dspy-ai[qdrant])
#   Downloading ujson-5.10.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.3 kB)
# Requirement already satisfied: httpx in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from dspy-ai[qdrant]) (0.27.2)
# Collecting magicattr~=0.1.6 (from dspy-ai[qdrant])
#   Downloading magicattr-0.1.6-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting diskcache (from dspy-ai[qdrant])
#   Downloading diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: qdrant-client in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from dspy-ai[qdrant]) (1.11.2)
# Requirement already satisfied: fastembed in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from dspy-ai[qdrant]) (0.3.6)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from openai<2.0.0,>=0.28.1->dspy-ai[qdrant]) (4.6.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from openai<2.0.0,>=0.28.1->dspy-ai[qdrant]) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from openai<2.0.0,>=0.28.1->dspy-ai[qdrant]) (0.5.0)
# Requirement already satisfied: sniffio in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from openai<2.0.0,>=0.28.1->dspy-ai[qdrant]) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from openai<2.0.0,>=0.28.1->dspy-ai[qdrant]) (4.12.2)
# Requirement already satisfied: certifi in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from httpx->dspy-ai[qdrant]) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from httpx->dspy-ai[qdrant]) (1.0.5)
# Requirement already satisfied: idna in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from httpx->dspy-ai[qdrant]) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from httpcore==1.*->httpx->dspy-ai[qdrant]) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from pydantic~=2.0->dspy-ai[qdrant]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from pydantic~=2.0->dspy-ai[qdrant]) (2.23.4)
# Requirement already satisfied: filelock in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from datasets->dspy-ai[qdrant]) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from datasets->dspy-ai[qdrant]) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from datasets->dspy-ai[qdrant]) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from datasets->dspy-ai[qdrant]) (0.3.8)
# Requirement already satisfied: xxhash in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from datasets->dspy-ai[qdrant]) (3.5.0)
# Requirement already satisfied: multiprocess in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from datasets->dspy-ai[qdrant]) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets->dspy-ai[qdrant]) (2024.6.1)
# Requirement already satisfied: aiohttp in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from datasets->dspy-ai[qdrant]) (3.10.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from datasets->dspy-ai[qdrant]) (0.25.0)
# Requirement already satisfied: packaging in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from datasets->dspy-ai[qdrant]) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from datasets->dspy-ai[qdrant]) (6.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from requests->dspy-ai[qdrant]) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from requests->dspy-ai[qdrant]) (2.2.3)
# Requirement already satisfied: PyStemmer<3.0.0,>=2.2.0 in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from fastembed->dspy-ai[qdrant]) (2.2.0.1)
# Requirement already satisfied: loguru<0.8.0,>=0.7.2 in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from fastembed->dspy-ai[qdrant]) (0.7.2)
# Requirement already satisfied: mmh3<5.0,>=4.0 in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from fastembed->dspy-ai[qdrant]) (4.1.0)
# Requirement already satisfied: onnx<2.0.0,>=1.15.0 in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from fastembed->dspy-ai[qdrant]) (1.16.2)
# Requirement already satisfied: onnxruntime<2.0.0,>=1.17.0 in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from fastembed->dspy-ai[qdrant]) (1.19.2)
# Requirement already satisfied: pillow<11.0.0,>=10.3.0 in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from fastembed->dspy-ai[qdrant]) (10.4.0)
# Requirement already satisfied: snowballstemmer<3.0.0,>=2.2.0 in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from fastembed->dspy-ai[qdrant]) (2.2.0)
# Requirement already satisfied: tokenizers<1.0,>=0.15 in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from fastembed->dspy-ai[qdrant]) (0.20.0)
# Collecting alembic>=1.5.0 (from optuna->dspy-ai[qdrant])
#   Downloading alembic-1.13.2-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna->dspy-ai[qdrant])
#   Using cached colorlog-6.8.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from optuna->dspy-ai[qdrant]) (2.0.35)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from pandas->dspy-ai[qdrant]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from pandas->dspy-ai[qdrant]) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from pandas->dspy-ai[qdrant]) (2024.1)
# Requirement already satisfied: grpcio>=1.41.0 in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from qdrant-client->dspy-ai[qdrant]) (1.66.1)
# Requirement already satisfied: grpcio-tools>=1.41.0 in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from qdrant-client->dspy-ai[qdrant]) (1.66.1)
# Requirement already satisfied: portalocker<3.0.0,>=2.7.0 in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from qdrant-client->dspy-ai[qdrant]) (2.10.1)
# Collecting Mako (from alembic>=1.5.0->optuna->dspy-ai[qdrant])
#   Using cached Mako-1.3.5-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from aiohttp->datasets->dspy-ai[qdrant]) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from aiohttp->datasets->dspy-ai[qdrant]) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from aiohttp->datasets->dspy-ai[qdrant]) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from aiohttp->datasets->dspy-ai[qdrant]) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from aiohttp->datasets->dspy-ai[qdrant]) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from aiohttp->datasets->dspy-ai[qdrant]) (1.11.1)
# Requirement already satisfied: protobuf<6.0dev,>=5.26.1 in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from grpcio-tools>=1.41.0->qdrant-client->dspy-ai[qdrant]) (5.28.2)
# Requirement already satisfied: setuptools in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from grpcio-tools>=1.41.0->qdrant-client->dspy-ai[qdrant]) (75.1.0)
# Requirement already satisfied: h2<5,>=3 in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from httpx[http2]>=0.20.0->qdrant-client->dspy-ai[qdrant]) (4.1.0)
# Requirement already satisfied: coloredlogs in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from onnxruntime<2.0.0,>=1.17.0->fastembed->dspy-ai[qdrant]) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from onnxruntime<2.0.0,>=1.17.0->fastembed->dspy-ai[qdrant]) (24.3.25)
# Requirement already satisfied: sympy in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from onnxruntime<2.0.0,>=1.17.0->fastembed->dspy-ai[qdrant]) (1.13.3)
# Requirement already satisfied: six>=1.5 in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->dspy-ai[qdrant]) (1.16.0)
# Requirement already satisfied: hyperframe<7,>=6.0 in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client->dspy-ai[qdrant]) (6.0.1)
# Requirement already satisfied: hpack<5,>=4.0 in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client->dspy-ai[qdrant]) (4.0.0)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from coloredlogs->onnxruntime<2.0.0,>=1.17.0->fastembed->dspy-ai[qdrant]) (10.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from Mako->alembic>=1.5.0->optuna->dspy-ai[qdrant]) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages (from sympy->onnxruntime<2.0.0,>=1.17.0->fastembed->dspy-ai[qdrant]) (1.3.0)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading magicattr-0.1.6-py2.py3-none-any.whl (4.7 kB)
# Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading diskcache-5.6.3-py3-none-any.whl (45 kB)
# Downloading dspy_ai-2.4.17-py3-none-any.whl (297 kB)
# Downloading optuna-4.0.0-py3-none-any.whl (362 kB)
# Downloading structlog-24.4.0-py3-none-any.whl (67 kB)
# Downloading ujson-5.10.0-cp312-cp312-macosx_11_0_arm64.whl (51 kB)
# Downloading alembic-1.13.2-py3-none-any.whl (232 kB)
# Using cached colorlog-6.8.2-py3-none-any.whl (11 kB)
# Using cached Mako-1.3.5-py3-none-any.whl (78 kB)
# Installing collected packages: magicattr, ujson, structlog, Mako, joblib, diskcache, colorlog, backoff, alembic, optuna, dspy-ai
# Successfully installed Mako-1.3.5 alembic-1.13.2 backoff-2.2.1 colorlog-6.8.2 diskcache-5.6.3 dspy-ai-2.4.17 joblib-1.4.2 magicattr-0.1.6 optuna-4.0.0 structlog-24.4.0 ujson-5.10.0

# %%
#Verify the version on DSPy
# !pip freeze | grep dspy
# Out:
# /Users/atitaarora/.zshenv:2: command too long: /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/bin:/opt/homebrew/bin:/opt/homebrew/sbin:/usr/local/bin:/System/Cryptexes/App/usr/bin:/usr/bin:/bin:/usr/sbin:/sbin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/local/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/appleinternal/bin:/Library/Apple/usr/bin:/Users/atitaarora/.cargo/bin:/Applications/iTerm.app/Contents/Resources/utilities=/Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/bin:/opt/homebrew/bin:/opt/homebrew/sbin:/usr/local/bin:/System/Cryptexes/App/usr/bin:/usr/bin:/bin:/usr/sbin:/sbin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/local/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/appleinternal/bin:/Library/Apple/usr/bin:/Users/atitaarora/.cargo/bin:/Applications/iTerm.app/Contents/Resources/utilities+,,/Users/atitaarora/Library/Python/3.10/bin
# dspy-ai==2.4.17

# %%
import dspy
from dspy.retrieve.qdrant_rm import QdrantRM

turbo = dspy.OpenAI(model="gpt-3.5-turbo")
qdrant_retriever_model = QdrantRM(COLLECTION_NAME, client, k=3)

dspy.settings.configure(lm=turbo, rm=qdrant_retriever_model)

retrieve = dspy.Retrieve(k=3)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 77.7M/77.7M [00:06<00:00, 11.7MiB/s]

# %%
topK_passages = retrieve(question2).passages

print(f"Top {retrieve.k} passages for question: {question2}", "\n")
for idx, passage in enumerate(topK_passages):
    print(f"{idx+1}]", passage, "\n")
# Out:
# Top 3 passages for question: How can one reproduce the benchmark for Open Source vector databases?
#
# 1] ## The Emergence and Relevance of Vector Databases
#
# 2] That makes the comparison unfair. That’s why we purely focused on testing the Open Source vector databases, so everybody may reproduce the benchmarks easily.
#
#
#
# This is not the final list, and we’ll continue benchmarking as many different engines as possible.
#
#
#
# ## How to reproduce the benchmark?
#
#
#
# The source code is available on [Github](https://github.com/qdrant/vector-db-benchmark) and has a `README.md` file describing the process of running the benchmark for a specific engine.
#
# 3] However, we tried our best, kept scrolling the docs up and down, experimented with combinations of different configurations, and gave all of them an equal chance to stand out. If you believe you can do it better than us, our **benchmarks are fully [open-sourced](https://github.com/qdrant/vector-db-benchmark), and contributions are welcome**!
#
#
#
#
#
# ## What do we measure?
#
#
#
# There are several factors considered while deciding on which database to use.

# %%
import dspy
from dspy.retrieve.qdrant_rm import QdrantRM
turbo = dspy.OpenAI(model="gpt-3.5-turbo")
qdrant_retriever_model = QdrantRM(COLLECTION_NAME, client, k=3)
dspy.settings.configure(lm=turbo, rm=qdrant_retriever_model)

class BasicQA(dspy.Signature):
    """Answer questions with provided context."""

    question = dspy.InputField()
    context = dspy.InputField(desc="This will contain relevant facts from the dataset")
    answer = dspy.OutputField(desc="Answer to the question asked")

def query_with_DSPy_CoT_context(query,limit):
    ## Fetch context from Qdrant using DsPy
    search_result_retrieve = dspy.Retrieve(k=limit)
    search_result = search_result_retrieve(query).passages
    generate_answer = dspy.ChainOfThought(BasicQA)
    # Call the predictor on a particular input alongside a hint.
    pred = generate_answer(question=query , context=search_result)
    return (search_result,pred.answer)
    
def query_with_DSPy_ReAct_context(query,limit):
    ## Fetch context from Qdrant using DsPy
    search_result_retrieve = dspy.Retrieve(k=limit)
    search_result = search_result_retrieve(query).passages
    generate_answer = dspy.ReAct(BasicQA)
    # Call the predictor on a particular input alongside a hint.
    pred = generate_answer(question=query , context=search_result)
    return (search_result, pred.answer)

# %%
pred_CoT = query_with_DSPy_CoT_context(question1,RETRIEVAL_SIZE_3)[1]
pred_CoT
# Out:
# 'Quantization is a process in which traditional float32 vectors are converted into qbit vectors in quantum computing. This allows for the creation of quantum entanglement between the qbits, enabling highly efficient vector search algorithms.'

# %%
pred_ReAct = query_with_DSPy_ReAct_context(question1,RETRIEVAL_SIZE_3)[1]
pred_ReAct
# Out:
# 'Quantum quantization is a novel approach that leverages the power of quantum computing to speed up the search process in ANNs by converting traditional float32 vectors into qbit vectors and creating quantum entanglement between them.'

# %%
pred_CoT_5 = query_with_DSPy_CoT_context(question1,RETRIEVAL_SIZE_5)[1]
pred_CoT_5
# Out:
# 'Quantum quantization is a novel approach that leverages the power of quantum computing to speed up the search process in artificial neural networks (ANNs). It involves converting traditional float32 vectors into qbit vectors to create quantum entanglement between the qbits, allowing for highly efficient vector search algorithms.'

# %%
pred_ReAct_5 = query_with_DSPy_ReAct_context(question1,RETRIEVAL_SIZE_5)[1]
pred_ReAct_5
# Out:
# 'Quantization is the process of converting traditional float32 vectors into qbit vectors to leverage the power of quantum computing for faster search processes in artificial neural networks.'

# %% [markdown]
# ### **14. Lets evaluate , how good is our RAG !!**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **14a. Test Evaluation Dataset Generation using Ragas**

# %%
from ragas.testset.generator import TestsetGenerator
from ragas.testset.evolutions import simple, reasoning, multi_context
from langchain_openai import ChatOpenAI, OpenAIEmbeddings

# generator with openai models
generator_llm = ChatOpenAI(model="gpt-3.5-turbo-16k")
critic_llm = ChatOpenAI(model="gpt-4")
embeddings = OpenAIEmbeddings()

generator = TestsetGenerator.from_langchain(generator_llm , critic_llm , embeddings)

# generate testset
testset = generator.generate_with_langchain_docs(langchain_docs[:10], test_size=10, 
                                                 distributions={simple: 0.5, reasoning: 0.25, multi_context: 0.25})
# Out:
# /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages/pysbd/segmenter.py:66: SyntaxWarning: invalid escape sequence '\s'
#   for match in re.finditer('{0}\s*'.format(re.escape(sent)), self.original_text):
# /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages/pysbd/lang/arabic.py:29: SyntaxWarning: invalid escape sequence '\.'
#   txt = re.sub('(?<={0})\.'.format(am), '∯', txt)
# /Users/atitaarora/qdrant/workspace/qdrant-rag-eval/workshop-rag-eval-oxford-llm2024/oxford-rag-eval/lib/python3.12/site-packages/pysbd/lang/persian.py:29: SyntaxWarning: invalid escape sequence '\.'
#   txt = re.sub('(?<={0})\.'.format(am), '∯', txt)
# Filename and doc_id are the same for all nodes.
# Generating: 100%|██████████████████████████████████████████████████████████████████| 10/10 [00:55<00:00,  5.55s/it]

# %% [markdown]
# ### **14b. Evaluation dataset to Pandas for better visualization**

# %%
df = testset.to_pandas()
df.head(10)
# Out:
#                                             question  \
# 0  How does Qdrant help IrisAgent in transforming...
# 1  How does Qdrant power AI solutions with unpara...
# 2  What is one of the capabilities showcased in t...
# 3  What is the role of performance in powering AI...
# 4  How is Qdrant used for similarity search in te...
# 5  What factors contribute to the success of Qdra...
# 6  How does Qdrant's performance contribute to AI...
# 7  How did VISUA use anomaly detection to improve...
# 8  What makes Qdrant advantageous for AI solution...
# 9  What is the role of massive-scale data process...
#
#                                             contexts  \
# 0  [---\n\ntitle: Customers\n\ndescription: Learn...
# 1  [---\n\ntitle: Customers\n\ndescription: Learn...
# 2  [---\n\ntitle: Qdrant Demos and Tutorials\n\nd...
# 3  [---\n\ntitle: Customers\n\ndescription: Learn...
# 4  [ Qdrant is by far my favorite one. It's super...
# 5  [---\n\nreview: “We LOVE Qdrant! The exception...
# 6  [---\n\ntitle: Customers\n\ndescription: Learn...
# 7  [---\n\ntitle: Customers\n\ndescription: Learn...
# 8  [---\n\ntitle: Customers\n\ndescription: Learn...
# 9  [---\n\ntitle: Customers\n\ndescription: Learn...
#
#                                         ground_truth evolution_type  \
# 0  Qdrant helps IrisAgent in transforming custome...         simple
# 1  Qdrant powers AI solutions with unparalleled e...         simple
# 2  One of the capabilities showcased in the Qdran...         simple
# 3  Performance plays a crucial role in powering A...         simple
# 4  At Kern AI, Qdrant is used for fast document r...         simple
# 5  The exceptional engineering, strong business v...      reasoning
# 6  Qdrant's performance contributes to AI solutio...      reasoning
# 7  VISUA improved quality control process for com...  multi_context
# 8  Qdrant is advantageous for AI solutions needin...  multi_context
# 9  Massive-scale data processing plays a crucial ...         simple
#
#                                             metadata  episode_done
# 0  [{'source': 'customers/customers-case-studies....          True
# 1        [{'source': 'customers/customers-hero.md'}]          True
# 2                     [{'source': 'demo/_index.md'}]          True
# 3        [{'source': 'customers/customers-hero.md'}]          True
# 4  [{'source': 'customers/customers-vector-space-...          True
# 5  [{'source': 'customers/customers-testimonial2....          True
# 6        [{'source': 'customers/customers-hero.md'}]          True
# 7  [{'source': 'customers/customers-case-studies....          True
# 8  [{'source': 'customers/customers-case-studies....          True
# 9        [{'source': 'customers/customers-hero.md'}]          True

# %% [markdown]
# ### **14c. Export the evaluation dataset to csv (if needed)**

# %%
from pathlib import Path
filepath = Path('sample_question_ragas_101.csv')
filepath.parent.mkdir(parents=True, exist_ok=True)
df.to_csv(filepath)

# %%
import pandas as pd
from datasets import Dataset

df = pd.read_csv('sample_question_ragas_101.csv')
testset = Dataset.from_pandas(df)

# %% [markdown]
# ### **15. Prepare the evaluation dataset to evaluate our RAG system**

# %%
from datasets import Dataset

# RAGAS Expect ['question', 'answer', 'contexts', 'ground_truths'] format
'''
{
    "question": ['What is quantization?', ...],
    "answer": [], ## answer
    "contexts": [], ## context
    "ground_truth": ## answer expected
}
'''
def create_eval_dataset(dataset, eval_size,retrieval_window_size):
    questions = []
    answers = []
    contexts = []
    ground_truths = []
    
    # Iterate over the first 10 entries
    for i in range(eval_size):
        entry = dataset[i]
        question = entry['question']
        questions.append(question)
        
        #uncomment : if using huggingface dataset 
        #answer = entry['answer'] 
        answer = entry['ground_truth']
        ground_truths.append(answer)
        context , rag_response = query_with_context(question,retrieval_window_size)
        contexts.append(context)
        answers.append(rag_response)
    
    rag_response_data = {
        "question": questions,
        "answer": answers,
        "contexts": contexts,
        "ground_truth": ground_truths
    }
    
    return rag_response_data


def create_eval_dataset_for_dspy(dataset, eval_size,retrieval_window_size):
    questions = []
    answers = []
    contexts = []
    ground_truths = []
    
    # Iterate over the first 10 entries
    for i in range(eval_size):
        entry = dataset[i]
        question = entry['question']
        questions.append(question)       
        #uncomment : if using huggingface dataset 
        #answer = entry['answer'] 
        answer = entry['ground_truth']
        ground_truths.append(answer)
        #context , rag_response = query_with_DSPy_CoT_context(question,retrieval_window_size)
        context , rag_response = query_with_DSPy_ReAct_context(question,retrieval_window_size)
        contexts.append(context)
        answers.append(rag_response)
    
    rag_response_data = {
        "question": questions,
        "answer": answers,
        "contexts": contexts,
        "ground_truth": ground_truths
    }
    
    return rag_response_data

# %%
from ragas.metrics import (
    faithfulness,
    answer_relevancy,
    context_recall,
    context_precision,
    context_utilization,
    context_entity_recall,
    answer_similarity,
    answer_correctness
)

# %%
## Method to encapsulate ragas evaluate method with all the 8 metrics
def evaluate_with_ragas(rag_response_dataset_df):
    result = evaluate(
        rag_response_dataset_df,
        metrics=[
                faithfulness,
                answer_relevancy,
                context_recall,
                context_precision,
                context_utilization,
                context_entity_recall,
                answer_similarity,
                answer_correctness
        ],
       raise_exceptions=False 
    )
    return result

# %% [markdown]
# ### **16. Let's get evaluating**
#
# Define the Config for generating the Eval dataset as below :

# %%
# loading the eval dataset from HuggingFace
#qdrant_qna_dataset = load_dataset("atitaarora/qdrant_doc_qna", split="train")

#or loading it from RAGAS generated questions
qdrant_qna_dataset = Dataset.from_pandas(df)

# %% [markdown]
# ### **16a. Evaluating with Retrieval window(number of chunks retrieved) = 3**

# %%
EVAL_SIZE = 10

RETRIEVAL_SIZE_3 = 3

#print(qdrant_qna_dataset.column_names)

## The dataset used to evaluate RAG using RAGAS
## Note this is the dataset needed for evaluation hence has to be recreated everytime changes to RAG config is made
rag_eval_dataset_512_3 = create_eval_dataset(qdrant_qna_dataset,EVAL_SIZE,RETRIEVAL_SIZE_3)

rag_eval_dataset_512_3
# Out:
# {'question': ['How does Qdrant help IrisAgent in transforming customer service?',
#   'How does Qdrant power AI solutions with unparalleled efficiency?',
#   'What is one of the capabilities showcased in the Qdrant Demos and Tutorials?',
#   'What is the role of performance in powering AI solutions that require vector search?',
#   'How is Qdrant used for similarity search in text data?',
#   "What factors contribute to the success of Qdrant's exceptional team?",
#   "How does Qdrant's performance contribute to AI solutions needing efficient vector search and massive-scale data processing?",
#   'How did VISUA use anomaly detection to improve computer vision quality control?',
#   'What makes Qdrant advantageous for AI solutions needing vector search, as shown in customer case studies?',
#   'What is the role of massive-scale data processing in powering AI solutions?'],
#  'answer': [' Qdrant is a powerful vector search engine that is integrated into IrisAgent\'s AI pipeline. It allows IrisAgent to automate support and improve resolution times by quickly and accurately retrieving relevant information from a large database of customer inquiries. This helps IrisAgent to provide efficient and effective customer service, ultimately transforming the customer support experience. You can learn more about Qdrant and its capabilities in the documentation, specifically in the "Overview" section of the "Vector Search" page.',
#   " According to the documentation, Qdrant powers thousands of top AI solutions with unparalleled efficiency, performance, and massive-scale data processing. This is achieved through its advanced vector search capabilities, which allow for fast and accurate retrieval of data. This information can be found in the 'Customers' section of the documentation, specifically in the 'Customers Hero' page.",
#   ' One of the capabilities showcased in the Qdrant Demos and Tutorials is vector search. This allows users to search for similar vectors within a dataset, making it easier to find relevant information. This is discussed in more detail in the "Vector Search" section of the "Overview" page in the documentation.',
#   ' Performance plays a crucial role in powering AI solutions that require vector search. According to Qdrant CEO André Zayarni, vector search is optimized for CPUs, and Intel\'s new CPU brings even more performance improvement, making vector operations blazing fast for AI applications. This means that customers should consider deploying more CPUs instead of GPU compute power to achieve the best performance results and reduce costs simultaneously. This information can be found in the blog post "Using Qdrant and Langchain" under the section "Why does vector search matter?" and in the blog post "Qdrant CPU Intel Benchmark" under the section "Why does vector search matter?" and the accompanying image.',
#   ' Qdrant is used for similarity search in text data through its advanced metadata filtering feature. This allows for custom logic to be incorporated during the similarity search, making it flexible for storing vectors with metadata in the form of payloads. This feature also helps reduce dimensionality and storage requirements, making it an efficient tool for text data similarity search. This information can be found in the "Reduced Dimensionality and Storage Requirements" section of the case study on Dailymotion, which can be accessed through the provided link.',
#   ' Qdrant\'s exceptional team is led by Andre Zayarni and is highly valued for their commitment to open-source and active engagement in helping users. This success can be attributed to their strong passion for data engineering and their exceptional support. This information can be found in the blog post "Case Study: Kairoswealth" in the "Support and Community" section, as well as in the blog post "Series A Funding Round" in the "What sets Qdrant apart?" section.',
#   ' According to the documentation, Qdrant powers thousands of top AI solutions that require vector search with unparalleled efficiency, performance, and massive-scale data processing. This means that Qdrant\'s performance is crucial in providing efficient and fast vector search for AI solutions that deal with large amounts of data. This is achieved through Qdrant\'s ability to handle hard problems related to implementing vector similarity at scale and in production settings. For more information on these challenges and how Qdrant helps solve them, please refer to the "Challenges with Vector Similarity Search" section in the blog post "What is Vector Similarity?" found in the source: "blog/what-is-vector-similarity.md".',
#   ' According to the case study "Visua and Qdrant: Vector Search in Computer Vision," VISUA implemented vector databases as a solution to the challenge of rapidly growing data volume and the limitations of their previous quality control processes. This allowed for more efficient and scalable anomaly detection, reducing the need for manual reviews and improving overall quality control. (Source: blog/case-study-visua.md)',
#   " Qdrant is advantageous for AI solutions needing vector search because it offers unparalleled efficiency, performance, and massive-scale data processing. This is evident in the thousands of top AI solutions that use Qdrant, as showcased in the customer case studies found in the 'Customers' section of the documentation. These case studies demonstrate how Qdrant's design choices enable it to power vector search use-cases that go beyond simple CRUD applications.",
#   " Massive-scale data processing plays a crucial role in powering AI solutions by providing the necessary data and infrastructure for AI and machine learning tools to function effectively. As mentioned in the documentation, the reliance on robust vector databases is increasing as companies integrate more sophisticated AI and machine learning tools. This highlights the importance of continuous hardware innovation, with Intel's contributions being a notable factor in shaping the future of enterprise-scale AI/ML solutions. (Source: blog/qdrant-cpu-intel-benchmark.md)"],
#  'contexts': [["document:## Optimizing IrisAgent's AI Pipeline: The Evaluation and Integration of Qdrant,source:blog/iris-agent-qdrant.md",
#    'document:---\n\ntitle: "IrisAgent and Qdrant: Redefining Customer Support with AI" \n\ndraft: false\n\nslug: iris-agent-qdrant\n\nshort_description: Pushing the boundaries of AI in customer support\n\ndescription: Learn how IrisAgent leverages Qdrant for RAG to automate support, and improve resolution times, transforming customer service\n\npreview_image: /case-studies/iris/irisagent-qdrant.png\n\n\n\ndate: 2024-03-06T07:45:34-08:00\n\nauthor: Manuel Meyer\n\nfeatured: false\n\ntags:\n\n  - news\n\n  - blog\n\n  - irisagent,source:blog/iris-agent-qdrant.md',
#    'document:## Why Qdrant?,source:documentation/overview/vector-search.md'],
#   ["document:## Optimizing IrisAgent's AI Pipeline: The Evaluation and Integration of Qdrant,source:blog/iris-agent-qdrant.md",
#    'document:#### Powering Vector Search & AI with Unmatched Data Sovereignty,source:blog/hybrid-cloud.md',
#    'document:---\n\ntitle: Customers\n\ndescription: Learn how Qdrant powers thousands of top AI solutions that require vector search with unparalleled efficiency, performance and massive-scale data processing.\n\nsitemapExclude: true\n\n---,source:customers/customers-hero.md'],
#   ['document:## What sets Qdrant apart?,source:blog/series-A-funding-round.md',
#    'document:technology, jump to the section most relevant to your use case.\n\n\n\nAs you go through the tutorials, please let us know if any questions come up in our \n\n[Discord channel here](https://qdrant.to/discord). 😎,source:documentation/overview/_index.md',
#    'document:## Why Qdrant?,source:documentation/overview/vector-search.md'],
#   ['document:#### Powering Vector Search & AI with Unmatched Data Sovereignty,source:blog/hybrid-cloud.md',
#    "document:The use of vector search in GenAI now has a name: **Retrieval Augmented Generation (RAG)**. [In our previous article](/articles/rag-is-dead/), we argued why RAG is an essential component of AI setups, and why large-scale AI can't operate without it. Numerous case studies explain that AI applications are simply too costly and resource-intensive to run using only LLMs. \n\n\n\n> Going forward, the solution is to leverage composite systems that use models and vector databases.,source:blog/using-qdrant-and-langchain.md",
#    'document:> *“Vector search is optimized for CPUs. Intel’s new CPU brings even more performance improvement and makes vector operations blazing fast for AI applications. Customers should consider deploying more CPUs instead of GPU compute power to achieve best performance results and reduce costs simultaneously.”* \n\n> \n\n> - André Zayarni, Qdrant CEO\n\n\n\n## **Why does vector search matter?**\n\n\n\n![qdrant cpu intel benchmark report](/blog/qdrant-cpu-intel-benchmark/qdrant-cpu-intel-benchmark-future.png),source:blog/qdrant-cpu-intel-benchmark.md'],
#   ['document:alt: Similarity\n\n  title: Semantic Search\n\n  description: Qdrant optimizes similarity search, identifying the closest database items to any query vector for applications like recommendation systems, RAG and image retrieval, enhancing accuracy and user experience.\n\n  link:\n\n    text: Learn More\n\n    url: /documentation/concepts/search/\n\n- id: 1\n\n  icon:\n\n    src: /icons/outline/search-text-blue.svg\n\n    alt: Search text\n\n  title: Hybrid Search for Text,source:advanced-search/advanced-search-features.md',
#    'document:## Project Overview\n\n\n\nQdrant is a powerful vector search engine widely used for similarity search and clustering. However, it lacked a user-friendly web-based UI for data visualization and exploration. My project aimed to bridge this gap by developing a web-based user interface that allows users to easily interact with and explore their vector data.\n\n\n\n## Milestones and Achievements,source:articles/web-ui-gsoc.md',
#    'document:Qdrant offers flexibility in storing vectors with metadata in form of payloads and offers support for  advanced metadata filtering during the similarity search to incorporate custom logic. \n\n\n\n\n\n**5. Reduced Dimensionality and Storage Requirements:**,source:blog/case-study-dailymotion.md'],
#   ['document:## Why Qdrant?,source:documentation/overview/vector-search.md',
#    "document:4. **Support and Community:** “The Qdrant team, led by Andre Zayarni, provides exceptional support and has a strong passion for data engineering,” notes Teyssier, “the team's commitment to open-source and their active engagement in helping users, from beginners to veterans, is highly valued by Kairoswealth.”\n\n\n\n### **Conclusion**,source:blog/case-study-kairoswealth.md",
#    'document:## What sets Qdrant apart?,source:blog/series-A-funding-round.md'],
#   ["document:## Optimizing IrisAgent's AI Pipeline: The Evaluation and Integration of Qdrant,source:blog/iris-agent-qdrant.md",
#    'document:---\n\ntitle: Customers\n\ndescription: Learn how Qdrant powers thousands of top AI solutions that require vector search with unparalleled efficiency, performance and massive-scale data processing.\n\nsitemapExclude: true\n\n---,source:customers/customers-hero.md',
#    'document:Due to its varied applications, vector similarity has become a critical component in AI tooling. However, implementing it at scale, and in production settings, poses some hard problems. Below we will discuss some of them and explore how Qdrant helps solve these challenges.\n\n\n\n## **Challenges with Vector Similarity Search**,source:blog/what-is-vector-similarity.md'],
#   ['document:Second, the rapid growth in data volume challenged their previous quality control processes, which relied on a sampling method based on meta-information (like analyzing lower-confidence, smaller, or blurry images), which involved more manual reviews and was not as scalable as needed. In response, the team at VISUA explored vector databases as a solution.\n\n\n\n## The Solution\n\n\n\n**Accelerating Anomaly Detection and Elevating Quality Control with Vector Search**,source:blog/case-study-visua.md',
#    'document:For over a decade, [VISUA](https://visua.com/) has been a leader in precise, high-volume computer vision data analysis, developing a robust platform that caters to a wide range of use cases, from startups to large enterprises,source:blog/case-study-visua.md',
#    'document:---\n\ndraft: false\n\ntitle: "Visua and Qdrant: Vector Search in Computer Vision"\n\nslug: \n\nshort_description: "Using vector search for quality control and anomaly detection in computer vision."\n\ndescription: "How Visua uses Qdrant as a vector search engine for quality control and anomaly detection in their computer vision platform."\n\npreview_image: /blog/case-study-visua/image4.png\n\nsocial_preview_image: /blog/case-study-visua/image4.png\n\ndate: 2024-05-01T00:02:00Z\n\nauthor: Manuel Meyer\n\nfeatured: false\n\ntags:,source:blog/case-study-visua.md'],
#   ['document:---\n\ntitle: Customers\n\ndescription: Learn how Qdrant powers thousands of top AI solutions that require vector search with unparalleled efficiency, performance and massive-scale data processing.\n\nsitemapExclude: true\n\n---,source:customers/customers-hero.md',
#    'document:To address these challenges head-on, we have made several design choices at Qdrant which help power vector search use-cases that go beyond simple CRUD applications.\n\n\n\n## How Qdrant Solves Vector Similarity Search Challenges,source:blog/what-is-vector-similarity.md',
#    'document:---\n\ntitle: Customers\n\ndescription: Learn how Qdrant powers thousands of top AI solutions that require vector search with unparalleled efficiency, performance and massive-scale data processing.\n\ncaseStudy:\n\n  logo:\n\n    src: /img/customers-case-studies/customer-logo.svg\n\n    alt: Logo\n\n  title: Recommendation Engine with Qdrant Vector Database,source:customers/customers-case-studies.md'],
#   ['document:#### Powering Vector Search & AI with Unmatched Data Sovereignty,source:blog/hybrid-cloud.md',
#    'document:### Scalability: Preparing for Sustained Growth in Data Volumes,source:blog/case-study-pienso.md',
#    "document:As large companies continue to integrate sophisticated AI and machine learning tools, the reliance on robust vector databases is going to increase. This evolution in the market underscores the importance of continuous hardware innovation in meeting the expanding demands of data-intensive applications, with Intel's contributions playing a notable role in shaping the future of enterprise-scale AI/ML solutions.\n\n\n\n## Next steps,source:blog/qdrant-cpu-intel-benchmark.md"]],
#  'ground_truth': ['Qdrant helps IrisAgent in transforming customer service by automating support and improving resolution times.',
#   'Qdrant powers AI solutions with unparalleled efficiency by providing vector search capabilities and massive-scale data processing. It is a powerful tool that enables thousands of top AI solutions to achieve high performance in their operations.',
#   'One of the capabilities showcased in the Qdrant Demos and Tutorials is semantic search, which leverages a pre-trained SentenceTransformer model to perform searches on startup descriptions.',
#   'Performance plays a crucial role in powering AI solutions that require vector search. Qdrant provides unparalleled efficiency and massive-scale data processing, enabling thousands of top AI solutions to deliver fast and accurate results.',
#   'At Kern AI, Qdrant is used for fast document retrieval and quick similarity search for text data.',
#   "The exceptional engineering, strong business value, and outstanding team behind the product contribute to the success of Qdrant's exceptional team.",
#   "Qdrant's performance contributes to AI solutions needing efficient vector search and massive-scale data processing by providing unparalleled efficiency and performance. It powers thousands of top AI solutions and enables them to process massive-scale data with ease.",
#   'VISUA improved quality control process for computer vision by 10x using anomaly detection.',
#   'Qdrant is advantageous for AI solutions needing vector search because it powers thousands of top AI solutions with unparalleled efficiency, performance, and massive-scale data processing. Customer case studies, such as Dailymotion, VISUA, Dust, and IrisAgent, demonstrate how Qdrant optimizes video recommendation engines, improves quality control processes, achieves millisecond retrieval, reduces costs, boosts scalability, and automates support to transform customer service.',
#   'Massive-scale data processing plays a crucial role in powering AI solutions. It enables efficient and high-performance vector search, which is essential for many AI applications.']}

# %%
rag_response_dataset_512_3 = Dataset.from_dict(rag_eval_dataset_512_3)
rag_response_dataset_512_3.to_csv('rag_response_512_3.csv')
# Out:
# Creating CSV from Arrow format: 100%|███████████████████████████████████████████████| 1/1 [00:00<00:00, 100.82ba/s]
# 16705

# %%
from ragas import evaluate
eval_dataset_512_3 = pd.read_csv('rag_response_512_3.csv')
eval_dataset_512_3.head(10)
# Out:
#                                             question  \
# 0  How does Qdrant help IrisAgent in transforming...
# 1  How does Qdrant power AI solutions with unpara...
# 2  What is one of the capabilities showcased in t...
# 3  What is the role of performance in powering AI...
# 4  How is Qdrant used for similarity search in te...
# 5  What factors contribute to the success of Qdra...
# 6  How does Qdrant's performance contribute to AI...
# 7  How did VISUA use anomaly detection to improve...
# 8  What makes Qdrant advantageous for AI solution...
# 9  What is the role of massive-scale data process...
#
#                                               answer  \
# 0   Qdrant is a powerful vector search engine tha...
# 1   According to the documentation, Qdrant powers...
# 2   One of the capabilities showcased in the Qdra...
# 3   Performance plays a crucial role in powering ...
# 4   Qdrant is used for similarity search in text ...
# 5   Qdrant's exceptional team is led by Andre Zay...
# 6   According to the documentation, Qdrant powers...
# 7   According to the case study "Visua and Qdrant...
# 8   Qdrant is advantageous for AI solutions needi...
# 9   Massive-scale data processing plays a crucial...
#
#                                             contexts  \
# 0  ["document:## Optimizing IrisAgent's AI Pipeli...
# 1  ["document:## Optimizing IrisAgent's AI Pipeli...
# 2  ['document:## What sets Qdrant apart?,source:b...
# 3  ['document:#### Powering Vector Search & AI wi...
# 4  ['document:alt: Similarity\n\n  title: Semanti...
# 5  ['document:## Why Qdrant?,source:documentation...
# 6  ["document:## Optimizing IrisAgent's AI Pipeli...
# 7  ['document:Second, the rapid growth in data vo...
# 8  ['document:---\n\ntitle: Customers\n\ndescript...
# 9  ['document:#### Powering Vector Search & AI wi...
#
#                                         ground_truth
# 0  Qdrant helps IrisAgent in transforming custome...
# 1  Qdrant powers AI solutions with unparalleled e...
# 2  One of the capabilities showcased in the Qdran...
# 3  Performance plays a crucial role in powering A...
# 4  At Kern AI, Qdrant is used for fast document r...
# 5  The exceptional engineering, strong business v...
# 6  Qdrant's performance contributes to AI solutio...
# 7  VISUA improved quality control process for com...
# 8  Qdrant is advantageous for AI solutions needin...
# 9  Massive-scale data processing plays a crucial ...

# %%
result_512_3 = evaluate(
        rag_response_dataset_512_3,
        metrics=[
                faithfulness,
                answer_relevancy,
                context_recall,
                context_precision,
                context_utilization,
                context_entity_recall,
                answer_similarity,
                answer_correctness
        ],
       raise_exceptions=False 
    )
# Out:
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 80/80 [00:32<00:00,  2.45it/s]

# %%
evaluation_result_df_512_3 = result_512_3.to_pandas()
evaluation_result_df_512_3.iloc[:10]
# Out:
#                                             question  \
# 0  How does Qdrant help IrisAgent in transforming...
# 1  How does Qdrant power AI solutions with unpara...
# 2  What is one of the capabilities showcased in t...
# 3  What is the role of performance in powering AI...
# 4  How is Qdrant used for similarity search in te...
# 5  What factors contribute to the success of Qdra...
# 6  How does Qdrant's performance contribute to AI...
# 7  How did VISUA use anomaly detection to improve...
# 8  What makes Qdrant advantageous for AI solution...
# 9  What is the role of massive-scale data process...
#
#                                             contexts  \
# 0  [document:## Optimizing IrisAgent's AI Pipelin...
# 1  [document:## Optimizing IrisAgent's AI Pipelin...
# 2  [document:## What sets Qdrant apart?,source:bl...
# 3  [document:#### Powering Vector Search & AI wit...
# 4  [document:alt: Similarity\n\n  title: Semantic...
# 5  [document:## Why Qdrant?,source:documentation/...
# 6  [document:## Optimizing IrisAgent's AI Pipelin...
# 7  [document:Second, the rapid growth in data vol...
# 8  [document:---\n\ntitle: Customers\n\ndescripti...
# 9  [document:#### Powering Vector Search & AI wit...
#
#                                               answer  \
# 0   Qdrant is a powerful vector search engine tha...
# 1   According to the documentation, Qdrant powers...
# 2   One of the capabilities showcased in the Qdra...
# 3   Performance plays a crucial role in powering ...
# 4   Qdrant is used for similarity search in text ...
# 5   Qdrant's exceptional team is led by Andre Zay...
# 6   According to the documentation, Qdrant powers...
# 7   According to the case study "Visua and Qdrant...
# 8   Qdrant is advantageous for AI solutions needi...
# 9   Massive-scale data processing plays a crucial...
#
#                                         ground_truth  faithfulness  \
# 0  Qdrant helps IrisAgent in transforming custome...      0.636364
# 1  Qdrant powers AI solutions with unparalleled e...      0.625000
# 2  One of the capabilities showcased in the Qdran...      0.000000
# 3  Performance plays a crucial role in powering A...      0.400000
# 4  At Kern AI, Qdrant is used for fast document r...      0.500000
# 5  The exceptional engineering, strong business v...      0.714286
# 6  Qdrant's performance contributes to AI solutio...      0.846154
# 7  VISUA improved quality control process for com...      0.333333
# 8  Qdrant is advantageous for AI solutions needin...      1.000000
# 9  Massive-scale data processing plays a crucial ...      0.666667
#
#    answer_relevancy  context_recall  context_precision  context_utilization  \
# 0          0.913649             1.0           0.500000             1.000000
# 1          0.916722             1.0           0.333333             0.333333
# 2          0.986222             0.0           0.000000             0.333333
# 3          0.992871             0.5           0.583333             1.000000
# 4          0.937597             0.0           1.000000             0.833333
# 5          0.877575             0.0           0.500000             0.500000
# 6          0.931168             1.0           0.583333             1.000000
# 7          0.891363             0.0           0.833333             0.833333
# 8          0.965497             0.5           0.833333             1.000000
# 9          0.981071             1.0           0.333333             0.333333
#
#    context_entity_recall  answer_similarity  answer_correctness
# 0               0.666667           0.903213            0.490509
# 1               0.200000           0.941457            0.535364
# 2               0.000000           0.867701            0.762380
# 3               0.333333           0.919175            0.329794
# 4               0.500000           0.884959            0.357603
# 5               1.000000           0.894074            0.652090
# 6               0.428571           0.937256            0.984322
# 7               0.750000           0.855478            0.380536
# 8               0.166667           0.953711            0.760167
# 9               0.000000           0.937643            0.534411

# %% [markdown]
# ### **16b. Improvision step by modifying the number of chunks retrieved to 4 and recreate the evaluation dataset**

# %%
## Define the Config for generating the Eval dataset as below :

# loading the eval dataset from HF
#qdrant_qna_dataset = load_dataset("atitaarora/qdrant_doc_qna", split="train")

EVAL_SIZE = 10

RETRIEVAL_SIZE_4 = 4

#print(qdrant_qna_dataset.column_names)

## The dataset used to evaluate RAG using RAGAS
## Note this is the dataset needed for evaluation hence has to be recreated everytime changes to RAG config is made
rag_eval_dataset_512_4 = create_eval_dataset(qdrant_qna_dataset,EVAL_SIZE,RETRIEVAL_SIZE_4)

# %%
#rag_response_data

## The dataset used to evaluate RAG using RAGAS
## Note this is the dataset needed for evaluation hence has to be recreated everytime changes to RAG config is made
rag_response_dataset_512_4 = Dataset.from_dict(rag_eval_dataset_512_4)
## Saving the evaluation dataset offline 
rag_response_dataset_512_4.to_csv('rag_response_512_4.csv')
# Out:
# Creating CSV from Arrow format: 100%|███████████████████████████████████████████████| 1/1 [00:00<00:00, 241.30ba/s]
# 21541

# %%
eval_dataset_512_4 = pd.read_csv('rag_response_512_4.csv')
eval_dataset_512_4.head(10)
# Out:
#                                             question  \
# 0  How does Qdrant help IrisAgent in transforming...
# 1  How does Qdrant power AI solutions with unpara...
# 2  What is one of the capabilities showcased in t...
# 3  What is the role of performance in powering AI...
# 4  How is Qdrant used for similarity search in te...
# 5  What factors contribute to the success of Qdra...
# 6  How does Qdrant's performance contribute to AI...
# 7  How did VISUA use anomaly detection to improve...
# 8  What makes Qdrant advantageous for AI solution...
# 9  What is the role of massive-scale data process...
#
#                                               answer  \
# 0   Qdrant helps IrisAgent in transforming custom...
# 1   Qdrant powers AI solutions with unparalleled ...
# 2   One of the capabilities showcased in the Qdra...
# 3   Performance plays a crucial role in powering ...
# 4   Qdrant is a powerful vector search engine tha...
# 5   Qdrant's exceptional team is led by Andre Zay...
# 6   Qdrant's performance is crucial for AI soluti...
# 7   VISUA implemented vector databases as a solut...
# 8   Qdrant is advantageous for AI solutions needi...
# 9   The role of massive-scale data processing is ...
#
#                                             contexts  \
# 0  ["document:## Optimizing IrisAgent's AI Pipeli...
# 1  ["document:## Optimizing IrisAgent's AI Pipeli...
# 2  ['document:## What sets Qdrant apart?,source:b...
# 3  ['document:#### Powering Vector Search & AI wi...
# 4  ['document:alt: Similarity\n\n  title: Semanti...
# 5  ['document:## Why Qdrant?,source:documentation...
# 6  ["document:## Optimizing IrisAgent's AI Pipeli...
# 7  ['document:Second, the rapid growth in data vo...
# 8  ['document:---\n\ntitle: Customers\n\ndescript...
# 9  ['document:#### Powering Vector Search & AI wi...
#
#                                         ground_truth
# 0  Qdrant helps IrisAgent in transforming custome...
# 1  Qdrant powers AI solutions with unparalleled e...
# 2  One of the capabilities showcased in the Qdran...
# 3  Performance plays a crucial role in powering A...
# 4  At Kern AI, Qdrant is used for fast document r...
# 5  The exceptional engineering, strong business v...
# 6  Qdrant's performance contributes to AI solutio...
# 7  VISUA improved quality control process for com...
# 8  Qdrant is advantageous for AI solutions needin...
# 9  Massive-scale data processing plays a crucial ...

# %%
result_512_4 = evaluate_with_ragas(rag_response_dataset_512_4)
# Out:
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 80/80 [00:34<00:00,  2.34it/s]

# %%
evaluation_result_df_512_4 = result_512_4.to_pandas()
evaluation_result_df_512_4.iloc[:10]
# Out:
#                                             question  \
# 0  How does Qdrant help IrisAgent in transforming...
# 1  How does Qdrant power AI solutions with unpara...
# 2  What is one of the capabilities showcased in t...
# 3  What is the role of performance in powering AI...
# 4  How is Qdrant used for similarity search in te...
# 5  What factors contribute to the success of Qdra...
# 6  How does Qdrant's performance contribute to AI...
# 7  How did VISUA use anomaly detection to improve...
# 8  What makes Qdrant advantageous for AI solution...
# 9  What is the role of massive-scale data process...
#
#                                             contexts  \
# 0  [document:## Optimizing IrisAgent's AI Pipelin...
# 1  [document:## Optimizing IrisAgent's AI Pipelin...
# 2  [document:## What sets Qdrant apart?,source:bl...
# 3  [document:#### Powering Vector Search & AI wit...
# 4  [document:alt: Similarity\n\n  title: Semantic...
# 5  [document:## Why Qdrant?,source:documentation/...
# 6  [document:## Optimizing IrisAgent's AI Pipelin...
# 7  [document:Second, the rapid growth in data vol...
# 8  [document:---\n\ntitle: Customers\n\ndescripti...
# 9  [document:#### Powering Vector Search & AI wit...
#
#                                               answer  \
# 0   Qdrant helps IrisAgent in transforming custom...
# 1   Qdrant powers AI solutions with unparalleled ...
# 2   One of the capabilities showcased in the Qdra...
# 3   Performance plays a crucial role in powering ...
# 4   Qdrant is a powerful vector search engine tha...
# 5   Qdrant's exceptional team is led by Andre Zay...
# 6   Qdrant's performance is crucial for AI soluti...
# 7   VISUA implemented vector databases as a solut...
# 8   Qdrant is advantageous for AI solutions needi...
# 9   The role of massive-scale data processing is ...
#
#                                         ground_truth  faithfulness  \
# 0  Qdrant helps IrisAgent in transforming custome...      0.846154
# 1  Qdrant powers AI solutions with unparalleled e...      1.000000
# 2  One of the capabilities showcased in the Qdran...      1.000000
# 3  Performance plays a crucial role in powering A...      0.714286
# 4  At Kern AI, Qdrant is used for fast document r...      0.727273
# 5  The exceptional engineering, strong business v...      0.818182
# 6  Qdrant's performance contributes to AI solutio...      0.900000
# 7  VISUA improved quality control process for com...      0.500000
# 8  Qdrant is advantageous for AI solutions needin...      1.000000
# 9  Massive-scale data processing plays a crucial ...      0.666667
#
#    answer_relevancy  context_recall  context_precision  context_utilization  \
# 0          1.000000             1.0           0.500000             1.000000
# 1          0.941115             1.0           0.416667             0.638889
# 2          0.986222             1.0           0.250000             0.250000
# 3          0.992871             0.5           0.638889             1.000000
# 4          0.886418             1.0           1.000000             1.000000
# 5          0.874683             0.0           0.500000             1.000000
# 6          0.938859             1.0           0.638889             1.000000
# 7          0.912786             0.0           0.805556             0.805556
# 8          0.965497             0.5           0.833333             0.833333
# 9          0.984398             1.0           0.333333             1.000000
#
#    context_entity_recall  answer_similarity  answer_correctness
# 0               0.666667           0.926969            0.512992
# 1               0.166667           0.933699            0.506152
# 2               0.000000           0.928403            0.482101
# 3               0.285714           0.908134            0.352033
# 4               0.500000           0.880054            0.327156
# 5               1.000000           0.859794            0.414948
# 6               0.285714           0.933427            0.420857
# 7               0.750000           0.848891            0.426508
# 8               0.166667           0.948249            0.558491
# 9               0.250000           0.936223            0.334056

# %% [markdown]
# ### **16c. Improvision step by modifying the number of chunks retrieved to 5 and recreate the evaluation dataset**

# %%
## Define the Config for generating the Eval dataset as below :

# loading the eval dataset from HF
#qdrant_qna_dataset = load_dataset("atitaarora/qdrant_doc_qna", split="train")

EVAL_SIZE = 10

RETRIEVAL_SIZE_5 = 5

#print(qdrant_qna_dataset.column_names)

## The dataset used to evaluate RAG using RAGAS
## Note this is the dataset needed for evaluation hence has to be recreated everytime changes to RAG config is made
rag_eval_dataset_512_5 = create_eval_dataset(qdrant_qna_dataset,EVAL_SIZE,RETRIEVAL_SIZE_5)

# %%
#rag_response_data

## The dataset used to evaluate RAG using RAGAS
## Note this is the dataset needed for evaluation hence has to be recreated everytime changes to RAG config is made
rag_response_dataset_512_5 = Dataset.from_dict(rag_eval_dataset_512_5)
## Saving the evaluation dataset offline 
rag_response_dataset_512_5.to_csv('rag_response_512_5.csv')
# Out:
# Creating CSV from Arrow format: 100%|███████████████████████████████████████████████| 1/1 [00:00<00:00, 252.27ba/s]
# 25733

# %%
from ragas import evaluate
eval_dataset_512_5 = pd.read_csv('rag_response_512_5.csv')
eval_dataset_512_5.head(10)
# Out:
#                                             question  \
# 0  How does Qdrant help IrisAgent in transforming...
# 1  How does Qdrant power AI solutions with unpara...
# 2  What is one of the capabilities showcased in t...
# 3  What is the role of performance in powering AI...
# 4  How is Qdrant used for similarity search in te...
# 5  What factors contribute to the success of Qdra...
# 6  How does Qdrant's performance contribute to AI...
# 7  How did VISUA use anomaly detection to improve...
# 8  What makes Qdrant advantageous for AI solution...
# 9  What is the role of massive-scale data process...
#
#                                               answer  \
# 0   Qdrant helps IrisAgent in transforming custom...
# 1   Qdrant powers AI solutions with unparalleled ...
# 2   One of the capabilities showcased in the Qdra...
# 3   Performance plays a crucial role in powering ...
# 4   Qdrant is a powerful vector search engine tha...
# 5   Qdrant's exceptional team is led by Andre Zay...
# 6   Qdrant's performance contributes to AI soluti...
# 7   VISUA used vector databases to enhance their ...
# 8   Qdrant is advantageous for AI solutions needi...
# 9   The role of massive-scale data processing in ...
#
#                                             contexts  \
# 0  ["document:## Optimizing IrisAgent's AI Pipeli...
# 1  ["document:## Optimizing IrisAgent's AI Pipeli...
# 2  ['document:## What sets Qdrant apart?,source:b...
# 3  ['document:#### Powering Vector Search & AI wi...
# 4  ['document:alt: Similarity\n\n  title: Semanti...
# 5  ['document:## Why Qdrant?,source:documentation...
# 6  ["document:## Optimizing IrisAgent's AI Pipeli...
# 7  ['document:Second, the rapid growth in data vo...
# 8  ['document:---\n\ntitle: Customers\n\ndescript...
# 9  ['document:#### Powering Vector Search & AI wi...
#
#                                         ground_truth
# 0  Qdrant helps IrisAgent in transforming custome...
# 1  Qdrant powers AI solutions with unparalleled e...
# 2  One of the capabilities showcased in the Qdran...
# 3  Performance plays a crucial role in powering A...
# 4  At Kern AI, Qdrant is used for fast document r...
# 5  The exceptional engineering, strong business v...
# 6  Qdrant's performance contributes to AI solutio...
# 7  VISUA improved quality control process for com...
# 8  Qdrant is advantageous for AI solutions needin...
# 9  Massive-scale data processing plays a crucial ...

# %%
result_512_5 = evaluate_with_ragas(rag_response_dataset_512_5)
# Out:
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 80/80 [00:30<00:00,  2.66it/s]

# %%
evaluation_result_df_512_5 = result_512_5.to_pandas()
evaluation_result_df_512_5.iloc[:10]
# Out:
#                                             question  \
# 0  How does Qdrant help IrisAgent in transforming...
# 1  How does Qdrant power AI solutions with unpara...
# 2  What is one of the capabilities showcased in t...
# 3  What is the role of performance in powering AI...
# 4  How is Qdrant used for similarity search in te...
# 5  What factors contribute to the success of Qdra...
# 6  How does Qdrant's performance contribute to AI...
# 7  How did VISUA use anomaly detection to improve...
# 8  What makes Qdrant advantageous for AI solution...
# 9  What is the role of massive-scale data process...
#
#                                             contexts  \
# 0  [document:## Optimizing IrisAgent's AI Pipelin...
# 1  [document:## Optimizing IrisAgent's AI Pipelin...
# 2  [document:## What sets Qdrant apart?,source:bl...
# 3  [document:#### Powering Vector Search & AI wit...
# 4  [document:alt: Similarity\n\n  title: Semantic...
# 5  [document:## Why Qdrant?,source:documentation/...
# 6  [document:## Optimizing IrisAgent's AI Pipelin...
# 7  [document:Second, the rapid growth in data vol...
# 8  [document:---\n\ntitle: Customers\n\ndescripti...
# 9  [document:#### Powering Vector Search & AI wit...
#
#                                               answer  \
# 0   Qdrant helps IrisAgent in transforming custom...
# 1   Qdrant powers AI solutions with unparalleled ...
# 2   One of the capabilities showcased in the Qdra...
# 3   Performance plays a crucial role in powering ...
# 4   Qdrant is a powerful vector search engine tha...
# 5   Qdrant's exceptional team is led by Andre Zay...
# 6   Qdrant's performance contributes to AI soluti...
# 7   VISUA used vector databases to enhance their ...
# 8   Qdrant is advantageous for AI solutions needi...
# 9   The role of massive-scale data processing in ...
#
#                                         ground_truth  faithfulness  \
# 0  Qdrant helps IrisAgent in transforming custome...      0.833333
# 1  Qdrant powers AI solutions with unparalleled e...      0.714286
# 2  One of the capabilities showcased in the Qdran...      0.666667
# 3  Performance plays a crucial role in powering A...      0.500000
# 4  At Kern AI, Qdrant is used for fast document r...      1.000000
# 5  The exceptional engineering, strong business v...      0.666667
# 6  Qdrant's performance contributes to AI solutio...      1.000000
# 7  VISUA improved quality control process for com...      1.000000
# 8  Qdrant is advantageous for AI solutions needin...      1.000000
# 9  Massive-scale data processing plays a crucial ...      0.583333
#
#    answer_relevancy  context_recall  context_precision  context_utilization  \
# 0          1.000000             1.0           0.533333             1.000000
# 1          0.940034             1.0           0.477778             0.679167
# 2          0.986222             1.0           0.250000             0.416667
# 3          0.992871             0.5           0.638889             1.000000
# 4          0.888659             0.0           1.000000             0.804167
# 5          0.919572             0.0           0.500000             1.000000
# 6          0.961555             1.0           0.679167             0.679167
# 7          0.968551             1.0           0.804167             0.755556
# 8          0.965497             0.5           0.833333             0.833333
# 9          0.984420             1.0           0.333333             1.000000
#
#    context_entity_recall  answer_similarity  answer_correctness
# 0               0.666667           0.921781            0.530445
# 1               0.200000           0.913049            0.697012
# 2               0.250000           0.922577            0.397311
# 3               0.333333           0.911168            0.343177
# 4               0.500000           0.870213            0.332938
# 5               1.000000           0.892093            0.223023
# 6               0.285714           0.939135            0.587725
# 7               0.750000           0.877129            0.519282
# 8               0.083333           0.947878            0.558398
# 9               0.250000           0.939567            0.334893

# %% [markdown]
# ### **16d. Evaluating with DSPy and Retrieval window(number of chunks retrieved) = 3**

# %%
## Generating Eval dataset for the given RAG pipeline
## Note this is the dataset needed for evaluation hence has to be recreated everytime changes to RAG config is made

rag_eval_dataset_dspy_512_3 = create_eval_dataset_for_dspy(qdrant_qna_dataset,EVAL_SIZE,RETRIEVAL_SIZE_3)
rag_eval_dataset_dspy_512_3
# Out:
# {'question': ['How does Qdrant help IrisAgent in transforming customer service?',
#   'How does Qdrant power AI solutions with unparalleled efficiency?',
#   'What is one of the capabilities showcased in the Qdrant Demos and Tutorials?',
#   'What is the role of performance in powering AI solutions that require vector search?',
#   'How is Qdrant used for similarity search in text data?',
#   "What factors contribute to the success of Qdrant's exceptional team?",
#   "How does Qdrant's performance contribute to AI solutions needing efficient vector search and massive-scale data processing?",
#   'How did VISUA use anomaly detection to improve computer vision quality control?',
#   'What makes Qdrant advantageous for AI solutions needing vector search, as shown in customer case studies?',
#   'What is the role of massive-scale data processing in powering AI solutions?'],
#  'answer': ['Qdrant helps IrisAgent in transforming customer service by automating support and improving resolution times.',
#   '',
#   'One of the capabilities showcased in the Qdrant Demos and Tutorials is Semantic Search Demo - Startup Search.',
#   'Performance plays a crucial role in powering AI solutions that require vector search by optimizing CPU operations for faster vector computations, reducing costs, and enabling the efficient deployment of composite systems using models and vector databases.',
#   'Qdrant is used for similarity search in text data by optimizing similarity search and identifying the closest database items to any query vector.',
#   "Exceptional support, passion for data engineering, commitment to open-source, and active engagement with users contribute to the success of Qdrant's exceptional team.",
#   "Qdrant's performance is likely optimized for efficiency and scalability by reducing dimensionality and storage requirements.",
#   'They leveraged vector databases for anomaly detection and quality control in their computer vision platform.',
#   "Qdrant's design choices help solve challenges in vector similarity search for AI solutions needing vector search.",
#   'Massive-scale data processing plays a crucial role in powering AI solutions by enabling the processing of large volumes of data, supporting complex AI algorithms, and facilitating the training of machine learning models.'],
#  'contexts': [["## Optimizing IrisAgent's AI Pipeline: The Evaluation and Integration of Qdrant",
#    '---\n\ntitle: "IrisAgent and Qdrant: Redefining Customer Support with AI" \n\ndraft: false\n\nslug: iris-agent-qdrant\n\nshort_description: Pushing the boundaries of AI in customer support\n\ndescription: Learn how IrisAgent leverages Qdrant for RAG to automate support, and improve resolution times, transforming customer service\n\npreview_image: /case-studies/iris/irisagent-qdrant.png\n\n\n\ndate: 2024-03-06T07:45:34-08:00\n\nauthor: Manuel Meyer\n\nfeatured: false\n\ntags:\n\n  - news\n\n  - blog\n\n  - irisagent',
#    '## Why Qdrant?'],
#   ["## Optimizing IrisAgent's AI Pipeline: The Evaluation and Integration of Qdrant",
#    '#### Powering Vector Search & AI with Unmatched Data Sovereignty',
#    '---\n\ntitle: Customers\n\ndescription: Learn how Qdrant powers thousands of top AI solutions that require vector search with unparalleled efficiency, performance and massive-scale data processing.\n\nsitemapExclude: true\n\n---'],
#   ['## What sets Qdrant apart?',
#    'technology, jump to the section most relevant to your use case.\n\n\n\nAs you go through the tutorials, please let us know if any questions come up in our \n\n[Discord channel here](https://qdrant.to/discord). 😎',
#    '## Why Qdrant?'],
#   ['#### Powering Vector Search & AI with Unmatched Data Sovereignty',
#    "The use of vector search in GenAI now has a name: **Retrieval Augmented Generation (RAG)**. [In our previous article](/articles/rag-is-dead/), we argued why RAG is an essential component of AI setups, and why large-scale AI can't operate without it. Numerous case studies explain that AI applications are simply too costly and resource-intensive to run using only LLMs. \n\n\n\n> Going forward, the solution is to leverage composite systems that use models and vector databases.",
#    '> *“Vector search is optimized for CPUs. Intel’s new CPU brings even more performance improvement and makes vector operations blazing fast for AI applications. Customers should consider deploying more CPUs instead of GPU compute power to achieve best performance results and reduce costs simultaneously.”* \n\n> \n\n> - André Zayarni, Qdrant CEO\n\n\n\n## **Why does vector search matter?**\n\n\n\n![qdrant cpu intel benchmark report](/blog/qdrant-cpu-intel-benchmark/qdrant-cpu-intel-benchmark-future.png)'],
#   ['alt: Similarity\n\n  title: Semantic Search\n\n  description: Qdrant optimizes similarity search, identifying the closest database items to any query vector for applications like recommendation systems, RAG and image retrieval, enhancing accuracy and user experience.\n\n  link:\n\n    text: Learn More\n\n    url: /documentation/concepts/search/\n\n- id: 1\n\n  icon:\n\n    src: /icons/outline/search-text-blue.svg\n\n    alt: Search text\n\n  title: Hybrid Search for Text',
#    '## Project Overview\n\n\n\nQdrant is a powerful vector search engine widely used for similarity search and clustering. However, it lacked a user-friendly web-based UI for data visualization and exploration. My project aimed to bridge this gap by developing a web-based user interface that allows users to easily interact with and explore their vector data.\n\n\n\n## Milestones and Achievements',
#    'Qdrant offers flexibility in storing vectors with metadata in form of payloads and offers support for  advanced metadata filtering during the similarity search to incorporate custom logic. \n\n\n\n\n\n**5. Reduced Dimensionality and Storage Requirements:**'],
#   ['## Why Qdrant?',
#    "4. **Support and Community:** “The Qdrant team, led by Andre Zayarni, provides exceptional support and has a strong passion for data engineering,” notes Teyssier, “the team's commitment to open-source and their active engagement in helping users, from beginners to veterans, is highly valued by Kairoswealth.”\n\n\n\n### **Conclusion**",
#    '## What sets Qdrant apart?'],
#   ["## Optimizing IrisAgent's AI Pipeline: The Evaluation and Integration of Qdrant",
#    '---\n\ntitle: Customers\n\ndescription: Learn how Qdrant powers thousands of top AI solutions that require vector search with unparalleled efficiency, performance and massive-scale data processing.\n\nsitemapExclude: true\n\n---',
#    'Due to its varied applications, vector similarity has become a critical component in AI tooling. However, implementing it at scale, and in production settings, poses some hard problems. Below we will discuss some of them and explore how Qdrant helps solve these challenges.\n\n\n\n## **Challenges with Vector Similarity Search**'],
#   ['Second, the rapid growth in data volume challenged their previous quality control processes, which relied on a sampling method based on meta-information (like analyzing lower-confidence, smaller, or blurry images), which involved more manual reviews and was not as scalable as needed. In response, the team at VISUA explored vector databases as a solution.\n\n\n\n## The Solution\n\n\n\n**Accelerating Anomaly Detection and Elevating Quality Control with Vector Search**',
#    'For over a decade, [VISUA](https://visua.com/) has been a leader in precise, high-volume computer vision data analysis, developing a robust platform that caters to a wide range of use cases, from startups to large enterprises',
#    '---\n\ndraft: false\n\ntitle: "Visua and Qdrant: Vector Search in Computer Vision"\n\nslug: \n\nshort_description: "Using vector search for quality control and anomaly detection in computer vision."\n\ndescription: "How Visua uses Qdrant as a vector search engine for quality control and anomaly detection in their computer vision platform."\n\npreview_image: /blog/case-study-visua/image4.png\n\nsocial_preview_image: /blog/case-study-visua/image4.png\n\ndate: 2024-05-01T00:02:00Z\n\nauthor: Manuel Meyer\n\nfeatured: false\n\ntags:'],
#   ['---\n\ntitle: Customers\n\ndescription: Learn how Qdrant powers thousands of top AI solutions that require vector search with unparalleled efficiency, performance and massive-scale data processing.\n\nsitemapExclude: true\n\n---',
#    'To address these challenges head-on, we have made several design choices at Qdrant which help power vector search use-cases that go beyond simple CRUD applications.\n\n\n\n## How Qdrant Solves Vector Similarity Search Challenges',
#    '---\n\ntitle: Customers\n\ndescription: Learn how Qdrant powers thousands of top AI solutions that require vector search with unparalleled efficiency, performance and massive-scale data processing.\n\ncaseStudy:\n\n  logo:\n\n    src: /img/customers-case-studies/customer-logo.svg\n\n    alt: Logo\n\n  title: Recommendation Engine with Qdrant Vector Database'],
#   ['#### Powering Vector Search & AI with Unmatched Data Sovereignty',
#    '### Scalability: Preparing for Sustained Growth in Data Volumes',
#    "As large companies continue to integrate sophisticated AI and machine learning tools, the reliance on robust vector databases is going to increase. This evolution in the market underscores the importance of continuous hardware innovation in meeting the expanding demands of data-intensive applications, with Intel's contributions playing a notable role in shaping the future of enterprise-scale AI/ML solutions.\n\n\n\n## Next steps"]],
#  'ground_truth': ['Qdrant helps IrisAgent in transforming customer service by automating support and improving resolution times.',
#   'Qdrant powers AI solutions with unparalleled efficiency by providing vector search capabilities and massive-scale data processing. It is a powerful tool that enables thousands of top AI solutions to achieve high performance in their operations.',
#   'One of the capabilities showcased in the Qdrant Demos and Tutorials is semantic search, which leverages a pre-trained SentenceTransformer model to perform searches on startup descriptions.',
#   'Performance plays a crucial role in powering AI solutions that require vector search. Qdrant provides unparalleled efficiency and massive-scale data processing, enabling thousands of top AI solutions to deliver fast and accurate results.',
#   'At Kern AI, Qdrant is used for fast document retrieval and quick similarity search for text data.',
#   "The exceptional engineering, strong business value, and outstanding team behind the product contribute to the success of Qdrant's exceptional team.",
#   "Qdrant's performance contributes to AI solutions needing efficient vector search and massive-scale data processing by providing unparalleled efficiency and performance. It powers thousands of top AI solutions and enables them to process massive-scale data with ease.",
#   'VISUA improved quality control process for computer vision by 10x using anomaly detection.',
#   'Qdrant is advantageous for AI solutions needing vector search because it powers thousands of top AI solutions with unparalleled efficiency, performance, and massive-scale data processing. Customer case studies, such as Dailymotion, VISUA, Dust, and IrisAgent, demonstrate how Qdrant optimizes video recommendation engines, improves quality control processes, achieves millisecond retrieval, reduces costs, boosts scalability, and automates support to transform customer service.',
#   'Massive-scale data processing plays a crucial role in powering AI solutions. It enables efficient and high-performance vector search, which is essential for many AI applications.']}

# %%
rag_response_dataset_dspy_512_3 = Dataset.from_dict(rag_eval_dataset_dspy_512_3)
rag_response_dataset_dspy_512_3.to_csv('rag_response_with_dspy_512_3.csv')
# Out:
# Creating CSV from Arrow format: 100%|███████████████████████████████████████████████| 1/1 [00:00<00:00, 222.91ba/s]
# 11472

# %%
from ragas import evaluate
eval_dataset_with_dspy_512_3 = pd.read_csv('rag_response_with_dspy_512_3.csv')
result_512_with_dspy_3 = evaluate(
        rag_response_dataset_dspy_512_3,
        metrics=[
                faithfulness,
                answer_relevancy,
                context_recall,
                context_precision,
                context_utilization,
                context_entity_recall,
                answer_similarity,
                answer_correctness
        ],
       raise_exceptions=False 
    )
# Out:
# Evaluating:  26%|█████████████████▎                                                | 21/80 [00:05<00:09,  6.52it/s]WARNING:ragas.metrics._faithfulness:No statements were generated from the answer.
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 80/80 [00:22<00:00,  3.50it/s]

# %%
evaluation_result_df_512_with_dspy_3 = result_512_with_dspy_3.to_pandas()
evaluation_result_df_512_with_dspy_3.iloc[:10]
# Out:
#                                             question  \
# 0  How does Qdrant help IrisAgent in transforming...
# 1  How does Qdrant power AI solutions with unpara...
# 2  What is one of the capabilities showcased in t...
# 3  What is the role of performance in powering AI...
# 4  How is Qdrant used for similarity search in te...
# 5  What factors contribute to the success of Qdra...
# 6  How does Qdrant's performance contribute to AI...
# 7  How did VISUA use anomaly detection to improve...
# 8  What makes Qdrant advantageous for AI solution...
# 9  What is the role of massive-scale data process...
#
#                                             contexts  \
# 0  [## Optimizing IrisAgent's AI Pipeline: The Ev...
# 1  [## Optimizing IrisAgent's AI Pipeline: The Ev...
# 2  [## What sets Qdrant apart?, technology, jump ...
# 3  [#### Powering Vector Search & AI with Unmatch...
# 4  [alt: Similarity\n\n  title: Semantic Search\n...
# 5  [## Why Qdrant?, 4. **Support and Community:**...
# 6  [## Optimizing IrisAgent's AI Pipeline: The Ev...
# 7  [Second, the rapid growth in data volume chall...
# 8  [---\n\ntitle: Customers\n\ndescription: Learn...
# 9  [#### Powering Vector Search & AI with Unmatch...
#
#                                               answer  \
# 0  Qdrant helps IrisAgent in transforming custome...
# 1
# 2  One of the capabilities showcased in the Qdran...
# 3  Performance plays a crucial role in powering A...
# 4  Qdrant is used for similarity search in text d...
# 5  Exceptional support, passion for data engineer...
# 6  Qdrant's performance is likely optimized for e...
# 7  They leveraged vector databases for anomaly de...
# 8  Qdrant's design choices help solve challenges ...
# 9  Massive-scale data processing plays a crucial ...
#
#                                         ground_truth  faithfulness  \
# 0  Qdrant helps IrisAgent in transforming custome...      1.000000
# 1  Qdrant powers AI solutions with unparalleled e...           NaN
# 2  One of the capabilities showcased in the Qdran...      0.000000
# 3  Performance plays a crucial role in powering A...      0.750000
# 4  At Kern AI, Qdrant is used for fast document r...      0.666667
# 5  The exceptional engineering, strong business v...      1.000000
# 6  Qdrant's performance contributes to AI solutio...      0.500000
# 7  VISUA improved quality control process for com...      1.000000
# 8  Qdrant is advantageous for AI solutions needin...      1.000000
# 9  Massive-scale data processing plays a crucial ...      0.500000
#
#    answer_relevancy  context_recall  context_precision  context_utilization  \
# 0          0.981905             1.0           0.500000             0.500000
# 1          0.000000             1.0           0.583333             0.000000
# 2          1.000000             0.0           0.000000             0.000000
# 3          0.992871             0.5           0.583333             0.583333
# 4          0.937597             0.0           1.000000             1.000000
# 5          0.979600             0.0           0.500000             0.500000
# 6          0.000000             1.0           0.583333             0.333333
# 7          0.917259             0.0           0.833333             0.833333
# 8          0.906504             0.5           0.833333             1.000000
# 9          0.970719             1.0           0.333333             0.333333
#
#    context_entity_recall  answer_similarity  answer_correctness
# 0               0.666667           1.000000            1.000000
# 1               0.200000           0.660203            0.165051
# 2               0.000000           0.944690            0.611173
# 3               0.333333           0.914820            0.528705
# 4               0.500000           0.924051            0.659584
# 5               1.000000           0.935626            0.779361
# 6               0.285714           0.915450            0.478863
# 7               0.750000           0.892315            0.523079
# 8               0.166667           0.925062            0.418765
# 9               0.000000           0.969770            0.456728

# %% [markdown]
# ### **16e. Evaluating with DSPy and Retrieval window(number of chunks retrieved) = 4**

# %%
## Generating Eval dataset for the given RAG pipeline
## Note this is the dataset needed for evaluation hence has to be recreated everytime changes to RAG config is made

rag_eval_dataset_dspy_512_4 = create_eval_dataset_for_dspy(qdrant_qna_dataset,EVAL_SIZE,RETRIEVAL_SIZE_4)
rag_eval_dataset_dspy_512_4
# Out:
# {'question': ['How does Qdrant help IrisAgent in transforming customer service?',
#   'How does Qdrant power AI solutions with unparalleled efficiency?',
#   'What is one of the capabilities showcased in the Qdrant Demos and Tutorials?',
#   'What is the role of performance in powering AI solutions that require vector search?',
#   'How is Qdrant used for similarity search in text data?',
#   "What factors contribute to the success of Qdrant's exceptional team?",
#   "How does Qdrant's performance contribute to AI solutions needing efficient vector search and massive-scale data processing?",
#   'How did VISUA use anomaly detection to improve computer vision quality control?',
#   'What makes Qdrant advantageous for AI solutions needing vector search, as shown in customer case studies?',
#   'What is the role of massive-scale data processing in powering AI solutions?'],
#  'answer': ["Qdrant enhances IrisAgent's AI pipeline, improving resolution times and automating support, ultimately transforming customer service.",
#   'Qdrant powers AI solutions with unparalleled efficiency by maximizing the customer value proposition.',
#   "The Semantic Search Demo - Startup Search showcases semantic search for startup descriptions through SentenceTransformer and Qdrant, comparing neural search's accuracy with traditional searches for better content discovery.",
#   'Performance is crucial for achieving optimal results and reducing costs in AI solutions that require vector search.',
#   'Qdrant is used for similarity search in text data by optimizing similarity search and identifying the closest database items to any query vector.',
#   "Factors contributing to the success of Qdrant's exceptional team include their support in implementation and assistance during difficult times.",
#   "Qdrant's performance contributes to AI solutions needing efficient vector search and massive-scale data processing by providing unparalleled efficiency and performance in powering thousands of AI solutions.",
#   'VISUA uses Qdrant as a vector search engine for quality control and anomaly detection in their computer vision platform.',
#   'Qdrant is advantageous for AI solutions needing vector search because it offers flexibility in storing vectors with metadata, supports advanced metadata filtering during similarity search, and reduces dimensionality and storage requirements.',
#   'Massive-scale data processing plays a crucial role in powering AI solutions by enabling the management of large data volumes, supporting sophisticated AI and machine learning tools, and ensuring data sovereignty and control for businesses.'],
#  'contexts': [["## Optimizing IrisAgent's AI Pipeline: The Evaluation and Integration of Qdrant",
#    '---\n\ntitle: "IrisAgent and Qdrant: Redefining Customer Support with AI" \n\ndraft: false\n\nslug: iris-agent-qdrant\n\nshort_description: Pushing the boundaries of AI in customer support\n\ndescription: Learn how IrisAgent leverages Qdrant for RAG to automate support, and improve resolution times, transforming customer service\n\npreview_image: /case-studies/iris/irisagent-qdrant.png\n\n\n\ndate: 2024-03-06T07:45:34-08:00\n\nauthor: Manuel Meyer\n\nfeatured: false\n\ntags:\n\n  - news\n\n  - blog\n\n  - irisagent',
#    '## Why Qdrant?',
#    "After the successful testing, Qdrant's outputs are now integrated into IrisAgent’s AI pipeline, enhancing a suite of proprietary AI models designed for tasks such as detecting hallucinations and similarities, and classifying customer intents. With Qdrant, IrisAgent saw significant performance and quality gains for their RAG use cases. Beyond this, IrisAgent also performs fine-tuning further in the development process."],
#   ["## Optimizing IrisAgent's AI Pipeline: The Evaluation and Integration of Qdrant",
#    '#### Powering Vector Search & AI with Unmatched Data Sovereignty',
#    '---\n\ntitle: Customers\n\ndescription: Learn how Qdrant powers thousands of top AI solutions that require vector search with unparalleled efficiency, performance and massive-scale data processing.\n\nsitemapExclude: true\n\n---',
#    'To meet the needs of the next generation of AI applications, Qdrant has always been built with four keys in mind: efficiency, scalability, performance, and flexibility. Our goal is to give our users unmatched speed and reliability, even when they are building massive-scale AI applications requiring the handling of billions of vectors. We did so by building Qdrant on Rust for performance, memory safety, and scale'],
#   ['## What sets Qdrant apart?',
#    'technology, jump to the section most relevant to your use case.\n\n\n\nAs you go through the tutorials, please let us know if any questions come up in our \n\n[Discord channel here](https://qdrant.to/discord). 😎',
#    '## Why Qdrant?',
#    '---\n\ntitle: Qdrant Demos and Tutorials\n\ndescription: Experience firsthand how Qdrant powers intelligent search, anomaly detection, and personalized recommendations, showcasing the full capabilities of vector search to revolutionize data exploration and insights.\n\ncards:\n\n  - id: 0\n\n    title: Semantic Search Demo - Startup Search\n\n    paragraphs:\n\n      - id: 0'],
#   ['#### Powering Vector Search & AI with Unmatched Data Sovereignty',
#    "The use of vector search in GenAI now has a name: **Retrieval Augmented Generation (RAG)**. [In our previous article](/articles/rag-is-dead/), we argued why RAG is an essential component of AI setups, and why large-scale AI can't operate without it. Numerous case studies explain that AI applications are simply too costly and resource-intensive to run using only LLMs. \n\n\n\n> Going forward, the solution is to leverage composite systems that use models and vector databases.",
#    '> *“Vector search is optimized for CPUs. Intel’s new CPU brings even more performance improvement and makes vector operations blazing fast for AI applications. Customers should consider deploying more CPUs instead of GPU compute power to achieve best performance results and reduce costs simultaneously.”* \n\n> \n\n> - André Zayarni, Qdrant CEO\n\n\n\n## **Why does vector search matter?**\n\n\n\n![qdrant cpu intel benchmark report](/blog/qdrant-cpu-intel-benchmark/qdrant-cpu-intel-benchmark-future.png)',
#    '---\n\nsubtitle: Powering the next generation of AI applications with advanced, high-performant vector similarity search technology.\n\nsocialMedia:\n\n  - id: 0'],
#   ['alt: Similarity\n\n  title: Semantic Search\n\n  description: Qdrant optimizes similarity search, identifying the closest database items to any query vector for applications like recommendation systems, RAG and image retrieval, enhancing accuracy and user experience.\n\n  link:\n\n    text: Learn More\n\n    url: /documentation/concepts/search/\n\n- id: 1\n\n  icon:\n\n    src: /icons/outline/search-text-blue.svg\n\n    alt: Search text\n\n  title: Hybrid Search for Text',
#    '## Project Overview\n\n\n\nQdrant is a powerful vector search engine widely used for similarity search and clustering. However, it lacked a user-friendly web-based UI for data visualization and exploration. My project aimed to bridge this gap by developing a web-based user interface that allows users to easily interact with and explore their vector data.\n\n\n\n## Milestones and Achievements',
#    'Qdrant offers flexibility in storing vectors with metadata in form of payloads and offers support for  advanced metadata filtering during the similarity search to incorporate custom logic. \n\n\n\n\n\n**5. Reduced Dimensionality and Storage Requirements:**',
#    '[Vector databases](https://qdrant.tech/), which introduce built-in full-text functionality, must make several compromises:\n\n\n\n- Choose a specific full-text search variant.\n\n- Either sacrifice API consistency or limit vector similarity functionality to only basic kNN search.\n\n- Introduce additional complexity to the system.\n\n\n\nQdrant, on the contrary, puts vector similarity in the center of its API and architecture, such that it allows us to move towards a new stack of vector-native operations.'],
#   ['## Why Qdrant?',
#    "4. **Support and Community:** “The Qdrant team, led by Andre Zayarni, provides exceptional support and has a strong passion for data engineering,” notes Teyssier, “the team's commitment to open-source and their active engagement in helping users, from beginners to veterans, is highly valued by Kairoswealth.”\n\n\n\n### **Conclusion**",
#    '## What sets Qdrant apart?',
#    'Qdrant distinguished itself through its:'],
#   ["## Optimizing IrisAgent's AI Pipeline: The Evaluation and Integration of Qdrant",
#    '---\n\ntitle: Customers\n\ndescription: Learn how Qdrant powers thousands of top AI solutions that require vector search with unparalleled efficiency, performance and massive-scale data processing.\n\nsitemapExclude: true\n\n---',
#    'Due to its varied applications, vector similarity has become a critical component in AI tooling. However, implementing it at scale, and in production settings, poses some hard problems. Below we will discuss some of them and explore how Qdrant helps solve these challenges.\n\n\n\n## **Challenges with Vector Similarity Search**',
#    '> *“Vector databases are a mainstay in today’s AI/ML toolchain, powering the latest generation of RAG and other Gen AI Applications. In teaming with Qdrant, Intel is helping enterprises deliver cutting-edge Gen-AI solutions and maximize their ROI by leveraging Qdrant’s high-performant and cost-efficient vector similarity search capabilities running on latest Intel Architecture based infrastructure across deployment models.”* \n\n>'],
#   ['Second, the rapid growth in data volume challenged their previous quality control processes, which relied on a sampling method based on meta-information (like analyzing lower-confidence, smaller, or blurry images), which involved more manual reviews and was not as scalable as needed. In response, the team at VISUA explored vector databases as a solution.\n\n\n\n## The Solution\n\n\n\n**Accelerating Anomaly Detection and Elevating Quality Control with Vector Search**',
#    'For over a decade, [VISUA](https://visua.com/) has been a leader in precise, high-volume computer vision data analysis, developing a robust platform that caters to a wide range of use cases, from startups to large enterprises',
#    '---\n\ndraft: false\n\ntitle: "Visua and Qdrant: Vector Search in Computer Vision"\n\nslug: \n\nshort_description: "Using vector search for quality control and anomaly detection in computer vision."\n\ndescription: "How Visua uses Qdrant as a vector search engine for quality control and anomaly detection in their computer vision platform."\n\npreview_image: /blog/case-study-visua/image4.png\n\nsocial_preview_image: /blog/case-study-visua/image4.png\n\ndate: 2024-05-01T00:02:00Z\n\nauthor: Manuel Meyer\n\nfeatured: false\n\ntags:',
#    '![visua/image3.png](/blog/case-study-visua/image3.png)\n\n\n\n## The Challenge\n\n\n\n**Quality Control at Scale**\n\n\n\nThe accuracy of object detection within images is critical for VISUA ensuring that their algorithms are detecting objects in images correctly. With growing volumes of data processed for clients, the company was looking for a way to enhance its quality control and anomaly detection mechanisms to be more scalable and auditable.'],
#   ['---\n\ntitle: Customers\n\ndescription: Learn how Qdrant powers thousands of top AI solutions that require vector search with unparalleled efficiency, performance and massive-scale data processing.\n\nsitemapExclude: true\n\n---',
#    'To address these challenges head-on, we have made several design choices at Qdrant which help power vector search use-cases that go beyond simple CRUD applications.\n\n\n\n## How Qdrant Solves Vector Similarity Search Challenges',
#    '---\n\ntitle: Customers\n\ndescription: Learn how Qdrant powers thousands of top AI solutions that require vector search with unparalleled efficiency, performance and massive-scale data processing.\n\ncaseStudy:\n\n  logo:\n\n    src: /img/customers-case-studies/customer-logo.svg\n\n    alt: Logo\n\n  title: Recommendation Engine with Qdrant Vector Database',
#    '---\n\ntitle: Qdrant Demos and Tutorials\n\ndescription: Experience firsthand how Qdrant powers intelligent search, anomaly detection, and personalized recommendations, showcasing the full capabilities of vector search to revolutionize data exploration and insights.\n\ncards:\n\n  - id: 0\n\n    title: Semantic Search Demo - Startup Search\n\n    paragraphs:\n\n      - id: 0'],
#   ['#### Powering Vector Search & AI with Unmatched Data Sovereignty',
#    '### Scalability: Preparing for Sustained Growth in Data Volumes',
#    "As large companies continue to integrate sophisticated AI and machine learning tools, the reliance on robust vector databases is going to increase. This evolution in the market underscores the importance of continuous hardware innovation in meeting the expanding demands of data-intensive applications, with Intel's contributions playing a notable role in shaping the future of enterprise-scale AI/ML solutions.\n\n\n\n## Next steps",
#    'In the rapidly evolving field of Artificial Intelligence and Machine Learning, the demand for being able to manage the modern AI stack within the existing infrastructure becomes increasingly relevant for businesses. As enterprises are launching new AI applications and use cases into production, they require the ability to maintain complete control over their data, since these new apps often work with sensitive internal and customer-centric data that needs to remain within the owned premises']],
#  'ground_truth': ['Qdrant helps IrisAgent in transforming customer service by automating support and improving resolution times.',
#   'Qdrant powers AI solutions with unparalleled efficiency by providing vector search capabilities and massive-scale data processing. It is a powerful tool that enables thousands of top AI solutions to achieve high performance in their operations.',
#   'One of the capabilities showcased in the Qdrant Demos and Tutorials is semantic search, which leverages a pre-trained SentenceTransformer model to perform searches on startup descriptions.',
#   'Performance plays a crucial role in powering AI solutions that require vector search. Qdrant provides unparalleled efficiency and massive-scale data processing, enabling thousands of top AI solutions to deliver fast and accurate results.',
#   'At Kern AI, Qdrant is used for fast document retrieval and quick similarity search for text data.',
#   "The exceptional engineering, strong business value, and outstanding team behind the product contribute to the success of Qdrant's exceptional team.",
#   "Qdrant's performance contributes to AI solutions needing efficient vector search and massive-scale data processing by providing unparalleled efficiency and performance. It powers thousands of top AI solutions and enables them to process massive-scale data with ease.",
#   'VISUA improved quality control process for computer vision by 10x using anomaly detection.',
#   'Qdrant is advantageous for AI solutions needing vector search because it powers thousands of top AI solutions with unparalleled efficiency, performance, and massive-scale data processing. Customer case studies, such as Dailymotion, VISUA, Dust, and IrisAgent, demonstrate how Qdrant optimizes video recommendation engines, improves quality control processes, achieves millisecond retrieval, reduces costs, boosts scalability, and automates support to transform customer service.',
#   'Massive-scale data processing plays a crucial role in powering AI solutions. It enables efficient and high-performance vector search, which is essential for many AI applications.']}

# %%
rag_response_dataset_dspy_512_4 = Dataset.from_dict(rag_eval_dataset_dspy_512_4)
rag_response_dataset_dspy_512_4.to_csv('rag_response_with_dspy_512_4.csv')
# Out:
# Creating CSV from Arrow format: 100%|███████████████████████████████████████████████| 1/1 [00:00<00:00, 156.01ba/s]
# 15521

# %%
from ragas import evaluate
eval_dataset_with_dspy_512_4 = pd.read_csv('rag_response_with_dspy_512_4.csv')
result_512_with_dspy_4 = evaluate(
        rag_response_dataset_dspy_512_4,
        metrics=[
                faithfulness,
                answer_relevancy,
                context_recall,
                context_precision,
                context_utilization,
                context_entity_recall,
                answer_similarity,
                answer_correctness
        ],
       raise_exceptions=False 
    )
# Out:
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 80/80 [00:29<00:00,  2.70it/s]

# %%
evaluation_result_df_512_with_dspy_4 = result_512_with_dspy_4.to_pandas()
evaluation_result_df_512_with_dspy_4.iloc[:10]
# Out:
#                                             question  \
# 0  How does Qdrant help IrisAgent in transforming...
# 1  How does Qdrant power AI solutions with unpara...
# 2  What is one of the capabilities showcased in t...
# 3  What is the role of performance in powering AI...
# 4  How is Qdrant used for similarity search in te...
# 5  What factors contribute to the success of Qdra...
# 6  How does Qdrant's performance contribute to AI...
# 7  How did VISUA use anomaly detection to improve...
# 8  What makes Qdrant advantageous for AI solution...
# 9  What is the role of massive-scale data process...
#
#                                             contexts  \
# 0  [## Optimizing IrisAgent's AI Pipeline: The Ev...
# 1  [## Optimizing IrisAgent's AI Pipeline: The Ev...
# 2  [## What sets Qdrant apart?, technology, jump ...
# 3  [#### Powering Vector Search & AI with Unmatch...
# 4  [alt: Similarity\n\n  title: Semantic Search\n...
# 5  [## Why Qdrant?, 4. **Support and Community:**...
# 6  [## Optimizing IrisAgent's AI Pipeline: The Ev...
# 7  [Second, the rapid growth in data volume chall...
# 8  [---\n\ntitle: Customers\n\ndescription: Learn...
# 9  [#### Powering Vector Search & AI with Unmatch...
#
#                                               answer  \
# 0  Qdrant enhances IrisAgent's AI pipeline, impro...
# 1  Qdrant powers AI solutions with unparalleled e...
# 2  The Semantic Search Demo - Startup Search show...
# 3  Performance is crucial for achieving optimal r...
# 4  Qdrant is used for similarity search in text d...
# 5  Factors contributing to the success of Qdrant'...
# 6  Qdrant's performance contributes to AI solutio...
# 7  VISUA uses Qdrant as a vector search engine fo...
# 8  Qdrant is advantageous for AI solutions needin...
# 9  Massive-scale data processing plays a crucial ...
#
#                                         ground_truth  faithfulness  \
# 0  Qdrant helps IrisAgent in transforming custome...      0.750000
# 1  Qdrant powers AI solutions with unparalleled e...      0.500000
# 2  One of the capabilities showcased in the Qdran...      0.000000
# 3  Performance plays a crucial role in powering A...      1.000000
# 4  At Kern AI, Qdrant is used for fast document r...      0.666667
# 5  The exceptional engineering, strong business v...      0.000000
# 6  Qdrant's performance contributes to AI solutio...      1.000000
# 7  VISUA improved quality control process for com...      1.000000
# 8  Qdrant is advantageous for AI solutions needin...      0.250000
# 9  Massive-scale data processing plays a crucial ...      1.000000
#
#    answer_relevancy  context_recall  context_precision  context_utilization  \
# 0          0.932352             1.0           0.500000             0.500000
# 1          0.947293             1.0           0.638889             0.416667
# 2          0.814545             1.0           0.250000             0.250000
# 3          0.947660             0.5           0.638889             0.583333
# 4          0.937597             0.0           1.000000             1.000000
# 5          0.988426             0.0           0.500000             0.500000
# 6          0.961917             1.0           0.638889             0.638889
# 7          0.875877             0.0           0.805556             0.416667
# 8          0.965497             0.5           0.833333             0.333333
# 9          0.970719             1.0           0.333333             0.416667
#
#    context_entity_recall  answer_similarity  answer_correctness
# 0               1.000000           0.978634            0.673230
# 1               0.166667           0.935902            0.448261
# 2               0.500000           0.950353            0.666160
# 3               0.333333           0.889072            0.722268
# 4               0.500000           0.924051            0.981013
# 5               1.000000           0.935351            0.233838
# 6               0.285714           0.994461            0.548615
# 7               0.750000           0.897244            0.474311
# 8               0.166667           0.942173            0.496413
# 9               0.250000           0.959143            0.454072

# %% [markdown]
# ### **16f. Evaluating with DSPy and Retrieval window(number of chunks retrieved) =5**

# %%
## Generating Eval dataset for the given RAG pipeline
## Note this is the dataset needed for evaluation hence has to be recreated everytime changes to RAG config is made

rag_eval_dataset_dspy_512_5 = create_eval_dataset_for_dspy(qdrant_qna_dataset,EVAL_SIZE,RETRIEVAL_SIZE_5)
rag_eval_dataset_dspy_512_5
# Out:
# {'question': ['How does Qdrant help IrisAgent in transforming customer service?',
#   'How does Qdrant power AI solutions with unparalleled efficiency?',
#   'What is one of the capabilities showcased in the Qdrant Demos and Tutorials?',
#   'What is the role of performance in powering AI solutions that require vector search?',
#   'How is Qdrant used for similarity search in text data?',
#   "What factors contribute to the success of Qdrant's exceptional team?",
#   "How does Qdrant's performance contribute to AI solutions needing efficient vector search and massive-scale data processing?",
#   'How did VISUA use anomaly detection to improve computer vision quality control?',
#   'What makes Qdrant advantageous for AI solutions needing vector search, as shown in customer case studies?',
#   'What is the role of massive-scale data processing in powering AI solutions?'],
#  'answer': ['Qdrant helps IrisAgent by automating support and improving resolution times, transforming customer service.',
#   'Qdrant maximizes efficiency in AI solutions by optimizing compute resources and scaling infrastructure efficiently.',
#   "The Semantic Search Demo - Startup Search showcases semantic search for startup descriptions through SentenceTransformer and Qdrant, comparing neural search's accuracy with traditional searches for better content discovery.",
#   'Performance plays a crucial role in powering AI solutions that require vector search by optimizing CPU operations for fast and efficient AI applications.',
#   'Qdrant is used for similarity search in text data by optimizing similarity search and identifying the closest database items to any query vector. It offers flexibility in storing vectors with metadata and supports advanced metadata filtering during similarity search.',
#   "The success of Qdrant's exceptional team is contributed by their strong support, passion for data engineering, commitment to open-source, and active engagement with users.",
#   "Qdrant's performance contributes to AI solutions needing efficient vector search and massive-scale data processing by providing high-performant and cost-efficient capabilities.",
#   'VISUA used vector databases to represent data uniquely and prioritize the review of anomalies and data points with the highest variance, allowing them to scale their quality assurance processes significantly.',
#   'Unmatched data sovereignty',
#   'Massive-scale data processing plays a crucial role in powering AI solutions by enabling robust vector databases, scalability for sustained growth in data volumes, and adapting to diverse AI development needs with customization and deployment flexibility.'],
#  'contexts': [["## Optimizing IrisAgent's AI Pipeline: The Evaluation and Integration of Qdrant",
#    '---\n\ntitle: "IrisAgent and Qdrant: Redefining Customer Support with AI" \n\ndraft: false\n\nslug: iris-agent-qdrant\n\nshort_description: Pushing the boundaries of AI in customer support\n\ndescription: Learn how IrisAgent leverages Qdrant for RAG to automate support, and improve resolution times, transforming customer service\n\npreview_image: /case-studies/iris/irisagent-qdrant.png\n\n\n\ndate: 2024-03-06T07:45:34-08:00\n\nauthor: Manuel Meyer\n\nfeatured: false\n\ntags:\n\n  - news\n\n  - blog\n\n  - irisagent',
#    '## Why Qdrant?',
#    "After the successful testing, Qdrant's outputs are now integrated into IrisAgent’s AI pipeline, enhancing a suite of proprietary AI models designed for tasks such as detecting hallucinations and similarities, and classifying customer intents. With Qdrant, IrisAgent saw significant performance and quality gains for their RAG use cases. Beyond this, IrisAgent also performs fine-tuning further in the development process.",
#    'url: /blog/dust-and-qdrant/\n\n- id: 2\n\n  logo:\n\n    src: /img/customers-case-studies/iris-agent.svg\n\n    alt: Logo\n\n  image:\n\n    src: /img/customers-case-studies/case-iris-agent.png\n\n    alt: Hands holding a smartphone, styled smartphone interface visualisation in the foreground. First-person view\n\n  title: IrisAgent uses Qdrant for RAG to automate support, and improve resolution times, transforming customer service.\n\n  link:\n\n    text: Read Story\n\n    url: /blog/iris-agent-qdrant/'],
#   ["## Optimizing IrisAgent's AI Pipeline: The Evaluation and Integration of Qdrant",
#    '#### Powering Vector Search & AI with Unmatched Data Sovereignty',
#    '---\n\ntitle: Customers\n\ndescription: Learn how Qdrant powers thousands of top AI solutions that require vector search with unparalleled efficiency, performance and massive-scale data processing.\n\nsitemapExclude: true\n\n---',
#    'To meet the needs of the next generation of AI applications, Qdrant has always been built with four keys in mind: efficiency, scalability, performance, and flexibility. Our goal is to give our users unmatched speed and reliability, even when they are building massive-scale AI applications requiring the handling of billions of vectors. We did so by building Qdrant on Rust for performance, memory safety, and scale',
#    '. Qdrant basically optimizes a lot using for the compute resources and this also helped us to scale the whole infrastructure in a really efficient manner.'],
#   ['## What sets Qdrant apart?',
#    'technology, jump to the section most relevant to your use case.\n\n\n\nAs you go through the tutorials, please let us know if any questions come up in our \n\n[Discord channel here](https://qdrant.to/discord). 😎',
#    '## Why Qdrant?',
#    '---\n\ntitle: Qdrant Demos and Tutorials\n\ndescription: Experience firsthand how Qdrant powers intelligent search, anomaly detection, and personalized recommendations, showcasing the full capabilities of vector search to revolutionize data exploration and insights.\n\ncards:\n\n  - id: 0\n\n    title: Semantic Search Demo - Startup Search\n\n    paragraphs:\n\n      - id: 0',
#    '#  src: /\n\n#  button: Watch Demo\n\n#  icon:\n\n#    src: /icons/outline/play-white.svg\n\n#    alt: Play\n\n#  preview: /img/qdrant-cloud-demo.png\n\nsitemapExclude: true\n\n---'],
#   ['#### Powering Vector Search & AI with Unmatched Data Sovereignty',
#    "The use of vector search in GenAI now has a name: **Retrieval Augmented Generation (RAG)**. [In our previous article](/articles/rag-is-dead/), we argued why RAG is an essential component of AI setups, and why large-scale AI can't operate without it. Numerous case studies explain that AI applications are simply too costly and resource-intensive to run using only LLMs. \n\n\n\n> Going forward, the solution is to leverage composite systems that use models and vector databases.",
#    '> *“Vector search is optimized for CPUs. Intel’s new CPU brings even more performance improvement and makes vector operations blazing fast for AI applications. Customers should consider deploying more CPUs instead of GPU compute power to achieve best performance results and reduce costs simultaneously.”* \n\n> \n\n> - André Zayarni, Qdrant CEO\n\n\n\n## **Why does vector search matter?**\n\n\n\n![qdrant cpu intel benchmark report](/blog/qdrant-cpu-intel-benchmark/qdrant-cpu-intel-benchmark-future.png)',
#    '---\n\nsubtitle: Powering the next generation of AI applications with advanced, high-performant vector similarity search technology.\n\nsocialMedia:\n\n  - id: 0',
#    '. This is a milestone for leveraging a managed vector search engine for data-sensitive AI applications.'],
#   ['alt: Similarity\n\n  title: Semantic Search\n\n  description: Qdrant optimizes similarity search, identifying the closest database items to any query vector for applications like recommendation systems, RAG and image retrieval, enhancing accuracy and user experience.\n\n  link:\n\n    text: Learn More\n\n    url: /documentation/concepts/search/\n\n- id: 1\n\n  icon:\n\n    src: /icons/outline/search-text-blue.svg\n\n    alt: Search text\n\n  title: Hybrid Search for Text',
#    '## Project Overview\n\n\n\nQdrant is a powerful vector search engine widely used for similarity search and clustering. However, it lacked a user-friendly web-based UI for data visualization and exploration. My project aimed to bridge this gap by developing a web-based user interface that allows users to easily interact with and explore their vector data.\n\n\n\n## Milestones and Achievements',
#    'Qdrant offers flexibility in storing vectors with metadata in form of payloads and offers support for  advanced metadata filtering during the similarity search to incorporate custom logic. \n\n\n\n\n\n**5. Reduced Dimensionality and Storage Requirements:**',
#    '[Vector databases](https://qdrant.tech/), which introduce built-in full-text functionality, must make several compromises:\n\n\n\n- Choose a specific full-text search variant.\n\n- Either sacrifice API consistency or limit vector similarity functionality to only basic kNN search.\n\n- Introduce additional complexity to the system.\n\n\n\nQdrant, on the contrary, puts vector similarity in the center of its API and architecture, such that it allows us to move towards a new stack of vector-native operations.',
#    '[Qdrant](https://qdrant.tech/) is a vector database and vector similarity search engine designed for efficient storage and retrieval of high-dimensional vectors. Because Qdrant offers efficient indexing and searching capabilities, it is ideal for implementing RAG solutions, where quickly and accurately retrieving relevant information from extremely large datasets is crucial. Qdrant also offers a wealth of additional features, such as quantization, multivector support and multi-tenancy.'],
#   ['## Why Qdrant?',
#    "4. **Support and Community:** “The Qdrant team, led by Andre Zayarni, provides exceptional support and has a strong passion for data engineering,” notes Teyssier, “the team's commitment to open-source and their active engagement in helping users, from beginners to veterans, is highly valued by Kairoswealth.”\n\n\n\n### **Conclusion**",
#    '## What sets Qdrant apart?',
#    'Qdrant distinguished itself through its:',
#    '. So you have really this need. And Qdrant was like an obvious choose. Actually, we did a benchmark, so we really tried several possibilities.'],
#   ["## Optimizing IrisAgent's AI Pipeline: The Evaluation and Integration of Qdrant",
#    '---\n\ntitle: Customers\n\ndescription: Learn how Qdrant powers thousands of top AI solutions that require vector search with unparalleled efficiency, performance and massive-scale data processing.\n\nsitemapExclude: true\n\n---',
#    'Due to its varied applications, vector similarity has become a critical component in AI tooling. However, implementing it at scale, and in production settings, poses some hard problems. Below we will discuss some of them and explore how Qdrant helps solve these challenges.\n\n\n\n## **Challenges with Vector Similarity Search**',
#    '> *“Vector databases are a mainstay in today’s AI/ML toolchain, powering the latest generation of RAG and other Gen AI Applications. In teaming with Qdrant, Intel is helping enterprises deliver cutting-edge Gen-AI solutions and maximize their ROI by leveraging Qdrant’s high-performant and cost-efficient vector similarity search capabilities running on latest Intel Architecture based infrastructure across deployment models.”* \n\n>',
#    'Qdrant offers flexibility in storing vectors with metadata in form of payloads and offers support for  advanced metadata filtering during the similarity search to incorporate custom logic. \n\n\n\n\n\n**5. Reduced Dimensionality and Storage Requirements:**'],
#   ['Second, the rapid growth in data volume challenged their previous quality control processes, which relied on a sampling method based on meta-information (like analyzing lower-confidence, smaller, or blurry images), which involved more manual reviews and was not as scalable as needed. In response, the team at VISUA explored vector databases as a solution.\n\n\n\n## The Solution\n\n\n\n**Accelerating Anomaly Detection and Elevating Quality Control with Vector Search**',
#    'For over a decade, [VISUA](https://visua.com/) has been a leader in precise, high-volume computer vision data analysis, developing a robust platform that caters to a wide range of use cases, from startups to large enterprises',
#    '---\n\ndraft: false\n\ntitle: "Visua and Qdrant: Vector Search in Computer Vision"\n\nslug: \n\nshort_description: "Using vector search for quality control and anomaly detection in computer vision."\n\ndescription: "How Visua uses Qdrant as a vector search engine for quality control and anomaly detection in their computer vision platform."\n\npreview_image: /blog/case-study-visua/image4.png\n\nsocial_preview_image: /blog/case-study-visua/image4.png\n\ndate: 2024-05-01T00:02:00Z\n\nauthor: Manuel Meyer\n\nfeatured: false\n\ntags:',
#    '![visua/image3.png](/blog/case-study-visua/image3.png)\n\n\n\n## The Challenge\n\n\n\n**Quality Control at Scale**\n\n\n\nThe accuracy of object detection within images is critical for VISUA ensuring that their algorithms are detecting objects in images correctly. With growing volumes of data processed for clients, the company was looking for a way to enhance its quality control and anomaly detection mechanisms to be more scalable and auditable.',
#    'The introduction of vectors allowed VISUA to represent data uniquely and mark frames for closer examination by prioritizing the review of anomalies and data points with the highest variance. Consequently, this technology empowered Visia to scale its quality assurance and reinforcement learning processes tenfold.'],
#   ['---\n\ntitle: Customers\n\ndescription: Learn how Qdrant powers thousands of top AI solutions that require vector search with unparalleled efficiency, performance and massive-scale data processing.\n\nsitemapExclude: true\n\n---',
#    'To address these challenges head-on, we have made several design choices at Qdrant which help power vector search use-cases that go beyond simple CRUD applications.\n\n\n\n## How Qdrant Solves Vector Similarity Search Challenges',
#    '---\n\ntitle: Customers\n\ndescription: Learn how Qdrant powers thousands of top AI solutions that require vector search with unparalleled efficiency, performance and massive-scale data processing.\n\ncaseStudy:\n\n  logo:\n\n    src: /img/customers-case-studies/customer-logo.svg\n\n    alt: Logo\n\n  title: Recommendation Engine with Qdrant Vector Database',
#    '---\n\ntitle: Qdrant Demos and Tutorials\n\ndescription: Experience firsthand how Qdrant powers intelligent search, anomaly detection, and personalized recommendations, showcasing the full capabilities of vector search to revolutionize data exploration and insights.\n\ncards:\n\n  - id: 0\n\n    title: Semantic Search Demo - Startup Search\n\n    paragraphs:\n\n      - id: 0',
#    'Due to its varied applications, vector similarity has become a critical component in AI tooling. However, implementing it at scale, and in production settings, poses some hard problems. Below we will discuss some of them and explore how Qdrant helps solve these challenges.\n\n\n\n## **Challenges with Vector Similarity Search**'],
#   ['#### Powering Vector Search & AI with Unmatched Data Sovereignty',
#    '### Scalability: Preparing for Sustained Growth in Data Volumes',
#    "As large companies continue to integrate sophisticated AI and machine learning tools, the reliance on robust vector databases is going to increase. This evolution in the market underscores the importance of continuous hardware innovation in meeting the expanding demands of data-intensive applications, with Intel's contributions playing a notable role in shaping the future of enterprise-scale AI/ML solutions.\n\n\n\n## Next steps",
#    'In the rapidly evolving field of Artificial Intelligence and Machine Learning, the demand for being able to manage the modern AI stack within the existing infrastructure becomes increasingly relevant for businesses. As enterprises are launching new AI applications and use cases into production, they require the ability to maintain complete control over their data, since these new apps often work with sensitive internal and customer-centric data that needs to remain within the owned premises',
#    '#### Adapting to Diverse AI Development Needs with Customization and Deployment Flexibility']],
#  'ground_truth': ['Qdrant helps IrisAgent in transforming customer service by automating support and improving resolution times.',
#   'Qdrant powers AI solutions with unparalleled efficiency by providing vector search capabilities and massive-scale data processing. It is a powerful tool that enables thousands of top AI solutions to achieve high performance in their operations.',
#   'One of the capabilities showcased in the Qdrant Demos and Tutorials is semantic search, which leverages a pre-trained SentenceTransformer model to perform searches on startup descriptions.',
#   'Performance plays a crucial role in powering AI solutions that require vector search. Qdrant provides unparalleled efficiency and massive-scale data processing, enabling thousands of top AI solutions to deliver fast and accurate results.',
#   'At Kern AI, Qdrant is used for fast document retrieval and quick similarity search for text data.',
#   "The exceptional engineering, strong business value, and outstanding team behind the product contribute to the success of Qdrant's exceptional team.",
#   "Qdrant's performance contributes to AI solutions needing efficient vector search and massive-scale data processing by providing unparalleled efficiency and performance. It powers thousands of top AI solutions and enables them to process massive-scale data with ease.",
#   'VISUA improved quality control process for computer vision by 10x using anomaly detection.',
#   'Qdrant is advantageous for AI solutions needing vector search because it powers thousands of top AI solutions with unparalleled efficiency, performance, and massive-scale data processing. Customer case studies, such as Dailymotion, VISUA, Dust, and IrisAgent, demonstrate how Qdrant optimizes video recommendation engines, improves quality control processes, achieves millisecond retrieval, reduces costs, boosts scalability, and automates support to transform customer service.',
#   'Massive-scale data processing plays a crucial role in powering AI solutions. It enables efficient and high-performance vector search, which is essential for many AI applications.']}

# %%
rag_response_dataset_dspy_512_5 = Dataset.from_dict(rag_eval_dataset_dspy_512_5)
rag_response_dataset_dspy_512_5.to_csv('rag_response_with_dspy_512_5.csv')
# Out:
# Creating CSV from Arrow format: 100%|███████████████████████████████████████████████| 1/1 [00:00<00:00, 225.11ba/s]
# 18162

# %%
from ragas import evaluate
eval_dataset_with_dspy_512_5 = pd.read_csv('rag_response_with_dspy_512_5.csv')
result_512_with_dspy_5 = evaluate(
        rag_response_dataset_dspy_512_5,
        metrics=[
                faithfulness,
                answer_relevancy,
                context_recall,
                context_precision,
                context_utilization,
                context_entity_recall,
                answer_similarity,
                answer_correctness
        ],
       raise_exceptions=False 
    )
# Out:
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 80/80 [00:28<00:00,  2.82it/s]

# %%
evaluation_result_df_512_with_dspy_5 = result_512_with_dspy_5.to_pandas()
evaluation_result_df_512_with_dspy_5.iloc[:10]
# Out:
#                                             question  \
# 0  How does Qdrant help IrisAgent in transforming...
# 1  How does Qdrant power AI solutions with unpara...
# 2  What is one of the capabilities showcased in t...
# 3  What is the role of performance in powering AI...
# 4  How is Qdrant used for similarity search in te...
# 5  What factors contribute to the success of Qdra...
# 6  How does Qdrant's performance contribute to AI...
# 7  How did VISUA use anomaly detection to improve...
# 8  What makes Qdrant advantageous for AI solution...
# 9  What is the role of massive-scale data process...
#
#                                             contexts  \
# 0  [## Optimizing IrisAgent's AI Pipeline: The Ev...
# 1  [## Optimizing IrisAgent's AI Pipeline: The Ev...
# 2  [## What sets Qdrant apart?, technology, jump ...
# 3  [#### Powering Vector Search & AI with Unmatch...
# 4  [alt: Similarity\n\n  title: Semantic Search\n...
# 5  [## Why Qdrant?, 4. **Support and Community:**...
# 6  [## Optimizing IrisAgent's AI Pipeline: The Ev...
# 7  [Second, the rapid growth in data volume chall...
# 8  [---\n\ntitle: Customers\n\ndescription: Learn...
# 9  [#### Powering Vector Search & AI with Unmatch...
#
#                                               answer  \
# 0  Qdrant helps IrisAgent by automating support a...
# 1  Qdrant maximizes efficiency in AI solutions by...
# 2  The Semantic Search Demo - Startup Search show...
# 3  Performance plays a crucial role in powering A...
# 4  Qdrant is used for similarity search in text d...
# 5  The success of Qdrant's exceptional team is co...
# 6  Qdrant's performance contributes to AI solutio...
# 7  VISUA used vector databases to represent data ...
# 8                         Unmatched data sovereignty
# 9  Massive-scale data processing plays a crucial ...
#
#                                         ground_truth  faithfulness  \
# 0  Qdrant helps IrisAgent in transforming custome...      1.000000
# 1  Qdrant powers AI solutions with unparalleled e...      0.666667
# 2  One of the capabilities showcased in the Qdran...      0.000000
# 3  Performance plays a crucial role in powering A...      1.000000
# 4  At Kern AI, Qdrant is used for fast document r...      0.800000
# 5  The exceptional engineering, strong business v...      1.000000
# 6  Qdrant's performance contributes to AI solutio...      1.000000
# 7  VISUA improved quality control process for com...      1.000000
# 8  Qdrant is advantageous for AI solutions needin...      0.000000
# 9  Massive-scale data processing plays a crucial ...      0.000000
#
#    answer_relevancy  context_recall  context_precision  context_utilization  \
# 0          0.975711             1.0           0.533333             0.887500
# 1          0.951044             1.0           0.477778             0.477778
# 2          0.814545             1.0           0.250000             0.250000
# 3          0.992871             0.5           0.638889             0.583333
# 4          0.938319             0.0           0.679167             0.804167
# 5          0.979600             0.0           0.500000             0.500000
# 6          0.961917             1.0           0.679167             1.000000
# 7          0.968344             1.0           0.804167             0.755556
# 8          0.869315             0.5           0.833333             0.000000
# 9          0.970726             0.0           0.333333             0.333333
#
#    context_entity_recall  answer_similarity  answer_correctness
# 0               0.666667           0.994596            0.677220
# 1               0.166667           0.930590            0.641746
# 2               0.666667           0.950353            0.612588
# 3               0.250000           0.915391            0.728848
# 4               0.500000           0.913974            0.853493
# 5               1.000000           0.931893            0.232973
# 6               0.285714           0.991180            0.581128
# 7               0.750000           0.896972            0.474243
# 8               0.083333           0.735406            0.267185
# 9               0.250000           0.977052            0.458549

# %% [markdown]
# ### **17. Compare results with the previous evaluation iteration**

# %%
## Result comparison
import pandas as pd
import matplotlib.pyplot as plt

def compare_dataframes(df1, df2 , df3 , df4 , df5 , df6):
    # Extract the specified columns from both dataframes
    headers = [ 'faithfulness',
                'answer_relevancy',
                'context_recall',
                'context_precision',
                'context_utilization',
                'context_entity_recall',
                'answer_similarity',
                'answer_correctness'
                ]
    
    # Create subplots
    fig, axes = plt.subplots(nrows=1, ncols=len(headers), figsize=(30, 5))
    
    # Plot bar plots for each header
    for i, header in enumerate(headers):
        ax = axes[i]
        ax.bar(['RW_3','RW_4', 'RW_5' , 'DSPy_3','DSPy_4', 'DSPy_5'], 
            [df1[header].mean(), df2[header].mean(), df3[header].mean(),df4[header].mean(),df5[header].mean(),df6[header].mean()])
        ax.set_title(header)
        ax.set_ylabel('Mean Value')
    
    # Adjust layout
    plt.tight_layout()
    
    # Show plot
    plt.show()

# %%
# Example result comparison:
compare_dataframes(evaluation_result_df_512_3, evaluation_result_df_512_4, evaluation_result_df_512_5 , 
                    evaluation_result_df_512_with_dspy_3, evaluation_result_df_512_with_dspy_4, evaluation_result_df_512_with_dspy_5)

# %% [markdown]
# ### **What does this mean?**
#
# We notice here that after DSPy our Retrieval-Augmented Generation (RAG) application shows improvements on :
# - Context Precision
# - Context Entity Recall
# - Answer Correctness
#
# and if affects the other metrics like :
# - Context Recall
# - Faithfulness
#
# which emphasises that there was certainly an improvement in retrieval & generation but there is still a room for betterment.
